# %% [markdown]
# # Week 4
# This week I reutilized my same LSTM Recurrent Neural Network approach from last week, but tried to be a bit more aggressive in the amount of stock I was purchasing and the amount of money I was spending.

# %%
pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.8.9.1)
# Requirement already satisfied: requests-html in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: feedparser in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (6.0.8)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (1.3.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (2.26.0)
# Requirement already satisfied: sgmllib3k in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->yahoo_fin) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->yahoo_fin) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (3.3)
# Requirement already satisfied: w3lib in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: pyquery in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: parse in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: bs4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: fake-useragent in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.2.6)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.8.2)
# Requirement already satisfied: websockets<10.0,>=9.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.62.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from bs4->requests-html->yahoo_fin) (4.10.0)
# Requirement already satisfied: lxml>=2.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (4.6.4)
# Requirement already satisfied: cssselect>0.7.9 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (1.3.4)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from yahoo_fin import stock_info as si

# %%
si.tickers_nasdaq()
# Out:
# ['AACG',
#  'AACI',
#  'AACIU',
#  'AACIW',
#  'AADI',
#  'AADR',
#  'AAL',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPL',
#  'AATC',
#  'AAWW',
#  'AAXJ',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEO',
#  'ABGI',
#  'ABIO',
#  'ABMD',
#  'ABNB',
#  'ABOS',
#  'ABSI',
#  'ABST',
#  'ABTX',
#  'ABUS',
#  'ABVC',
#  'ACAD',
#  'ACAH',
#  'ACAHU',
#  'ACAHW',
#  'ACB',
#  'ACBA',
#  'ACBAU',
#  'ACBAW',
#  'ACBI',
#  'ACCD',
#  'ACER',
#  'ACET',
#  'ACEV',
#  'ACEVU',
#  'ACEVW',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACHC',
#  'ACHL',
#  'ACHV',
#  'ACIU',
#  'ACIW',
#  'ACKIT',
#  'ACKIU',
#  'ACKIW',
#  'ACLS',
#  'ACMR',
#  'ACNB',
#  'ACOR',
#  'ACQR',
#  'ACQRU',
#  'ACQRW',
#  'ACRS',
#  'ACRX',
#  'ACST',
#  'ACT',
#  'ACTD',
#  'ACTDU',
#  'ACTDW',
#  'ACTG',
#  'ACVA',
#  'ACWI',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADALU',
#  'ADAP',
#  'ADBE',
#  'ADER',
#  'ADERU',
#  'ADERW',
#  'ADES',
#  'ADGI',
#  'ADI',
#  'ADIL',
#  'ADILW',
#  'ADMA',
#  'ADMP',
#  'ADN',
#  'ADNWW',
#  'ADOC',
#  'ADOCR',
#  'ADOCW',
#  'ADP',
#  'ADPT',
#  'ADRE',
#  'ADSK',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADVWW',
#  'ADXN',
#  'ADXS',
#  'AEAC',
#  'AEACU',
#  'AEACW',
#  'AEAEU',
#  'AEHA',
#  'AEHAU',
#  'AEHAW',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEMD',
#  'AEP',
#  'AEPPL',
#  'AEPPZ',
#  'AERC',
#  'AERI',
#  'AESE',
#  'AEY',
#  'AEYE',
#  'AEZS',
#  'AFACU',
#  'AFAQ',
#  'AFAQU',
#  'AFAQW',
#  'AFBI',
#  'AFCG',
#  'AFIB',
#  'AFIN',
#  'AFINO',
#  'AFINP',
#  'AFMD',
#  'AFRM',
#  'AFYA',
#  'AGBA',
#  'AGBAR',
#  'AGBAU',
#  'AGBAW',
#  'AGC',
#  'AGCUU',
#  'AGCWW',
#  'AGEN',
#  'AGFS',
#  'AGFY',
#  'AGGR',
#  'AGGRU',
#  'AGGRW',
#  'AGIL',
#  'AGILW',
#  'AGIO',
#  'AGLE',
#  'AGMH',
#  'AGNC',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGNG',
#  'AGRI',
#  'AGRIW',
#  'AGRX',
#  'AGTC',
#  'AGYS',
#  'AGZD',
#  'AHCO',
#  'AHI',
#  'AHPA',
#  'AHPAU',
#  'AHPAW',
#  'AHPI',
#  'AIA',
#  'AIH',
#  'AIHS',
#  'AIKI',
#  'AIMC',
#  'AINV',
#  'AIP',
#  'AIQ',
#  'AIRG',
#  'AIRR',
#  'AIRS',
#  'AIRT',
#  'AIRTP',
#  'AKAM',
#  'AKBA',
#  'AKIC',
#  'AKICU',
#  'AKICW',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKU',
#  'AKUS',
#  'AKYA',
#  'ALAC',
#  'ALACR',
#  'ALACU',
#  'ALACW',
#  'ALBO',
#  'ALCO',
#  'ALDX',
#  'ALEC',
#  'ALF',
#  'ALFIW',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIM',
#  'ALJJ',
#  'ALKS',
#  'ALKT',
#  'ALLK',
#  'ALLO',
#  'ALLT',
#  'ALNA',
#  'ALNY',
#  'ALORU',
#  'ALOT',
#  'ALPA',
#  'ALPAU',
#  'ALPAW',
#  'ALPN',
#  'ALPP',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALT',
#  'ALTM',
#  'ALTO',
#  'ALTR',
#  'ALTU',
#  'ALTUU',
#  'ALTUW',
#  'ALTY',
#  'ALVR',
#  'ALXO',
#  'ALYA',
#  'ALZN',
#  'AMAL',
#  'AMAO',
#  'AMAOU',
#  'AMAOW',
#  'AMAT',
#  'AMBA',
#  'AMCI',
#  'AMCIU',
#  'AMCIW',
#  'AMCX',
#  'AMD',
#  'AMED',
#  'AMEH',
#  'AMGN',
#  'AMKR',
#  'AMNB',
#  'AMOT',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPL',
#  'AMRK',
#  'AMRN',
#  'AMRS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMSWA',
#  'AMTB',
#  'AMTI',
#  'AMTX',
#  'AMWD',
#  'AMYT',
#  'AMZN',
#  'ANAB',
#  'ANAT',
#  'ANDE',
#  'ANEB',
#  'ANGI',
#  'ANGL',
#  'ANGN',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANPC',
#  'ANSS',
#  'ANTE',
#  'ANY',
#  'ANZU',
#  'ANZUU',
#  'ANZUW',
#  'AOSL',
#  'AOUT',
#  'APA',
#  'APAC',
#  'APACU',
#  'APACW',
#  'APDN',
#  'APEI',
#  'APEN',
#  'API',
#  'APLS',
#  'APLT',
#  'APM',
#  'APMI',
#  'APMIU',
#  'APMIW',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPH',
#  'APPHW',
#  'APPN',
#  'APPS',
#  'APR',
#  'APRE',
#  'APTM',
#  'APTMU',
#  'APTMW',
#  'APTO',
#  'APTX',
#  'APVO',
#  'APWC',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQST',
#  'AQWA',
#  'ARAV',
#  'ARAY',
#  'ARBE',
#  'ARBEW',
#  'ARBG',
#  'ARBGU',
#  'ARBGW',
#  'ARBK',
#  'ARBKL',
#  'ARCB',
#  'ARCC',
#  'ARCE',
#  'ARCKU',
#  'ARCT',
#  'ARDS',
#  'ARDX',
#  'AREC',
#  'ARGU',
#  'ARGUU',
#  'ARGUW',
#  'ARGX',
#  'ARHS',
#  'ARIZU',
#  'ARKO',
#  'ARKOW',
#  'ARKR',
#  'ARLP',
#  'ARNA',
#  'AROW',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARRW',
#  'ARRWU',
#  'ARRWW',
#  'ARRY',
#  'ARTA',
#  'ARTAU',
#  'ARTAW',
#  'ARTE',
#  'ARTEU',
#  'ARTEW',
#  'ARTL',
#  'ARTLW',
#  'ARTNA',
#  'ARTW',
#  'ARVL',
#  'ARVN',
#  'ARWR',
#  'ARYD',
#  'ARYE',
#  'ASAX',
#  'ASAXU',
#  'ASAXW',
#  'ASET',
#  'ASLE',
#  'ASLEW',
#  'ASLN',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASO',
#  'ASPA',
#  'ASPAU',
#  'ASPAW',
#  'ASPC',
#  'ASPCU',
#  'ASPCW',
#  'ASPS',
#  'ASPU',
#  'ASRT',
#  'ASRV',
#  'ASTC',
#  'ASTE',
#  'ASTL',
#  'ASTLW',
#  'ASTR',
#  'ASTRW',
#  'ASTS',
#  'ASTSW',
#  'ASUR',
#  'ASYS',
#  'ATAI',
#  'ATAX',
#  'ATCOL',
#  'ATCX',
#  'ATEC',
#  'ATER',
#  'ATEX',
#  'ATHA',
#  'ATHE',
#  'ATHX',
#  'ATIF',
#  'ATLC',
#  'ATLCL',
#  'ATLCP',
#  'ATLO',
#  'ATNF',
#  'ATNFW',
#  'ATNI',
#  'ATNX',
#  'ATOM',
#  'ATOS',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATRS',
#  'ATSG',
#  'ATSPT',
#  'ATSPU',
#  'ATSPW',
#  'ATVC',
#  'ATVCU',
#  'ATVCW',
#  'ATVI',
#  'ATXI',
#  'ATXS',
#  'ATY',
#  'AUB',
#  'AUBAP',
#  'AUBN',
#  'AUDC',
#  'AUGX',
#  'AUID',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AURC',
#  'AURCU',
#  'AURCW',
#  'AUROW',
#  'AUTL',
#  'AUTO',
#  'AUUD',
#  'AUUDW',
#  'AUVI',
#  'AUVIP',
#  'AVACU',
#  'AVAH',
#  'AVAV',
#  'AVCO',
#  'AVCT',
#  'AVCTW',
#  'AVDL',
#  'AVDX',
#  'AVEO',
#  'AVGO',
#  'AVGOP',
#  'AVGR',
#  'AVHI',
#  'AVHIU',
#  'AVHIW',
#  'AVID',
#  'AVIR',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVPTW',
#  'AVRO',
#  'AVT',
#  'AVTE',
#  'AVTX',
#  'AVXL',
#  'AWH',
#  'AWRE',
#  'AXDX',
#  'AXGN',
#  'AXLA',
#  'AXNX',
#  'AXON',
#  'AXSM',
#  'AXTI',
#  'AY',
#  'AYLA',
#  'AYRO',
#  'AYTU',
#  'AZN',
#  'AZPN',
#  'AZYO',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BASE',
#  'BATRA',
#  'BATRK',
#  'BBBY',
#  'BBCP',
#  'BBGI',
#  'BBH',
#  'BBI',
#  'BBIG',
#  'BBIO',
#  'BBLG',
#  'BBLGW',
#  'BBQ',
#  'BBSI',
#  'BCAB',
#  'BCAC',
#  'BCACU',
#  'BCACW',
#  'BCBP',
#  'BCDA',
#  'BCDAW',
#  'BCEL',
#  'BCLI',
#  'BCML',
#  'BCOR',
#  'BCOV',
#  'BCOW',
#  'BCPC',
#  'BCRX',
#  'BCSAU',
#  'BCTX',
#  'BCTXW',
#  'BCYC',
#  'BDSI',
#  'BDSX',
#  'BDTX',
#  'BEAM',
#  'BEAT',
#  'BEATW',
#  'BECN',
#  'BEEM',
#  'BEEMW',
#  'BELFA',
#  'BELFB',
#  'BENE',
#  'BENER',
#  'BENEU',
#  'BENEW',
#  'BFC',
#  'BFI',
#  'BFIIW',
#  'BFIN',
#  'BFIT',
#  'BFRA',
#  'BFRI',
#  'BFRIW',
#  'BFST',
#  'BGCP',
#  'BGFV',
#  'BGNE',
#  'BGRN',
#  'BGRY',
#  'BGRYW',
#  'BHAC',
#  'BHACU',
#  'BHACW',
#  'BHAT',
#  'BHF',
#  'BHFAL',
#  'BHFAM',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BHSE',
#  'BHSEU',
#  'BHSEW',
#  'BHTG',
#  'BIB',
#  'BICK',
#  'BIDU',
#  'BIGC',
#  'BIIB',
#  'BILI',
#  'BIMI',
#  'BIOC',
#  'BIOL',
#  'BIOT',
#  'BIOTU',
#  'BIOTW',
#  'BIOX',
#  'BIRD',
#  'BIS',
#  'BITF',
#  'BITS',
#  'BIVI',
#  'BJDX',
#  'BJK',
#  'BJRI',
#  'BKCC',
#  'BKCH',
#  'BKEP',
#  'BKEPP',
#  'BKNG',
#  'BKSC',
#  'BKYI',
#  'BL',
#  'BLBD',
#  'BLBX',
#  'BLCM',
#  'BLCN',
#  'BLCT',
#  'BLDE',
#  'BLDEW',
#  'BLDP',
#  'BLEUU',
#  'BLFS',
#  'BLFY',
#  'BLI',
#  'BLIN',
#  'BLKB',
#  'BLMN',
#  'BLNG',
#  'BLNGU',
#  'BLNGW',
#  'BLNK',
#  'BLNKW',
#  'BLPH',
#  'BLRX',
#  'BLSA',
#  'BLTS',
#  'BLTSU',
#  'BLTSW',
#  'BLU',
#  'BLUE',
#  'BLZE',
#  'BMAQ',
#  'BMAQR',
#  'BMAQU',
#  'BMAQW',
#  'BMBL',
#  'BMEA',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BMTC',
#  'BND',
#  'BNDW',
#  'BNDX',
#  'BNFT',
#  'BNGO',
#  'BNGOW',
#  'BNIX',
#  'BNIXR',
#  'BNIXW',
#  'BNNR',
#  'BNNRU',
#  'BNNRW',
#  'BNR',
#  'BNSO',
#  'BNTC',
#  'BNTX',
#  'BOKF',
#  'BOLT',
#  'BOMN',
#  'BON',
#  'BOOM',
#  'BOSC',
#  'BOTJ',
#  'BOTZ',
#  'BOXL',
#  'BPMC',
#  'BPOP',
#  'BPOPM',
#  'BPRN',
#  'BPTH',
#  'BPTS',
#  'BPYPM',
#  'BPYPN',
#  'BPYPO',
#  'BPYPP',
#  'BRAG',
#  'BRCN',
#  'BREZ',
#  'BREZR',
#  'BREZW',
#  'BRID',
#  'BRIV',
#  'BRIVU',
#  'BRIVW',
#  'BRKL',
#  'BRKR',
#  'BRKS',
#  'BRLI',
#  'BRLIR',
#  'BRLIU',
#  'BRLIW',
#  'BRLT',
#  'BROG',
#  'BROGW',
#  'BRP',
#  'BRPM',
#  'BRPMU',
#  'BRPMW',
#  'BRQS',
#  'BRTX',
#  'BRY',
#  'BRZE',
#  'BSAE',
#  'BSBE',
#  'BSBK',
#  'BSCE',
#  'BSCL',
#  'BSCM',
#  'BSCN',
#  'BSCO',
#  'BSCP',
#  'BSCQ',
#  'BSCR',
#  'BSCS',
#  'BSCT',
#  'BSCU',
#  'BSCV',
#  'BSDE',
#  'BSET',
#  'BSFC',
#  'BSGA',
#  'BSGAR',
#  'BSGAU',
#  'BSGM',
#  'BSJL',
#  'BSJM',
#  'BSJN',
#  'BSJO',
#  'BSJP',
#  'BSJQ',
#  'BSJR',
#  'BSJS',
#  'BSJT',
#  'BSKY',
#  'BSKYU',
#  'BSKYW',
#  'BSML',
#  'BSMM',
#  'BSMN',
#  'BSMO',
#  'BSMP',
#  'BSMQ',
#  'BSMR',
#  'BSMS',
#  'BSMT',
#  'BSMU',
#  'BSMV',
#  'BSQR',
#  'BSRR',
#  'BSVN',
#  'BSY',
#  'BTAI',
#  'BTAQ',
#  'BTAQU',
#  'BTAQW',
#  'BTB',
#  'BTBD',
#  'BTBDW',
#  'BTBT',
#  'BTCS',
#  'BTCY',
#  'BTEC',
#  'BTF',
#  'BTNB',
#  'BTRS',
#  'BTRSW',
#  'BTTX',
#  'BTWN',
#  'BTWNU',
#  'BTWNW',
#  'BTX',
#  'BUG',
#  'BUSE',
#  'BVS',
#  'BVXV',
#  'BWAC',
#  'BWACU',
#  'BWACW',
#  'BWAY',
#  'BWB',
#  'BWBBP',
#  'BWC',
#  'BWCAU',
#  'BWCAW',
#  'BWEN',
#  'BWFG',
#  'BWMN',
#  'BWMX',
#  'BXRX',
#  'BYFC',
#  'BYND',
#  'BYRN',
#  'BYSI',
#  'BYTS',
#  'BYTSU',
#  'BYTSW',
#  'BZ',
#  'BZUN',
#  'CAAS',
#  'CABA',
#  'CAC',
#  'CACC',
#  'CACG',
#  'CADL',
#  'CAKE',
#  'CALA',
#  'CALB',
#  'CALM',
#  'CALT',
#  'CAMP',
#  'CAMT',
#  'CAN',
#  'CAPR',
#  'CAR',
#  'CARA',
#  'CARE',
#  'CARG',
#  'CARV',
#  'CARZ',
#  'CASA',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CATC',
#  'CATH',
#  'CATY',
#  'CBAN',
#  'CBAT',
#  'CBAY',
#  'CBFV',
#  'CBIO',
#  'CBNK',
#  'CBRGU',
#  'CBRL',
#  'CBSH',
#  'CBTX',
#  'CCAI',
#  'CCAIU',
#  'CCAIW',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCCC',
#  'CCD',
#  'CCEL',
#  'CCEP',
#  'CCLP',
#  'CCMP',
#  'CCNC',
#  'CCNE',
#  'CCNEP',
#  'CCOI',
#  'CCRN',
#  'CCSI',
#  'CCTSU',
#  'CCXI',
#  'CD',
#  'CDAK',
#  'CDAQU',
#  'CDC',
#  'CDEV',
#  'CDK',
#  'CDL',
#  'CDLX',
#  'CDMO',
#  'CDNA',
#  'CDNS',
#  'CDTX',
#  'CDW',
#  'CDXC',
#  'CDXS',
#  'CDZI',
#  'CDZIP',
#  'CECE',
#  'CEFA',
#  'CELC',
#  'CELH',
#  'CELU',
#  'CELUW',
#  'CEMI',
#  'CENQ',
#  'CENQU',
#  'CENQW',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CERE',
#  'CERN',
#  'CERS',
#  'CERT',
#  'CETX',
#  'CETXP',
#  'CETXW',
#  'CEVA',
#  'CEY',
#  'CFA',
#  'CFB',
#  'CFBK',
#  'CFFE',
#  'CFFEU',
#  'CFFEW',
#  'CFFI',
#  'CFFN',
#  'CFFVU',
#  'CFFVW',
#  'CFIV',
#  'CFIVU',
#  'CFIVW',
#  'CFLT',
#  'CFMS',
#  'CFO',
#  'CFRX',
#  'CFV',
#  'CFVI',
#  'CFVIU',
#  'CFVIW',
#  'CG',
#  'CGABL',
#  'CGBD',
#  'CGC',
#  'CGEM',
#  'CGEN',
#  'CGNT',
#  'CGNX',
#  'CGO',
#  'CGRN',
#  'CGTX',
#  'CHB',
#  'CHCI',
#  'CHCO',
#  'CHDN',
#  'CHEF',
#  'CHEK',
#  'CHEKZ',
#  'CHI',
#  'CHK',
#  'CHKEL',
#  'CHKEW',
#  'CHKEZ',
#  'CHKP',
#  'CHMG',
#  'CHNA',
#  'CHNG',
#  'CHNGU',
#  'CHNR',
#  'CHPM',
#  'CHPMU',
#  'CHPMW',
#  'CHRS',
#  'CHRW',
#  'CHSCL',
#  'CHSCM',
#  'CHSCN',
#  'CHSCO',
#  'CHSCP',
#  'CHTR',
#  'CHUY',
#  'CHW',
#  'CHWA',
#  'CHWAU',
#  'CHWAW',
#  'CHX',
#  'CHY',
#  'CIBR',
#  'CID',
#  'CIDM',
#  'CIFR',
#  'CIFRW',
#  'CIGI',
#  'CIH',
#  'CIIG',
#  'CIIGU',
#  'CIIGW',
#  'CIL',
#  ...]

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: scipy>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: numpy>=1.14.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from collections import deque

# %%
features = ['adjclose', 'volume', 'open', 'high', 'low']

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (2.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (0.22.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: absl-py>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: numpy>=1.14.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (1.21.4)
# Requirement already satisfied: tensorboard~=2.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (4.0.0)
# Requirement already satisfied: libclang>=9.0.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.0.2)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (47.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.3.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.7)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
def get_data(ticker, window=50, predict=1):
    df = si.get_data(ticker)
    output = {}
    output['original df'] = df.copy()

    for col in features: 
        if col not in features:
            return f'Missing {col}'
    
    if 'date' not in df.columns:
        df['date'] = df.index

    scalers = {}
    for feature in features:
        scaler = MinMaxScaler()
        df[feature] = scaler.fit_transform(np.expand_dims(df[feature].values, axis=1))
        scalers[feature] = scaler
    output['scalers'] = scalers
    
    df['predicted'] = df['adjclose'].shift(-predict)
    last_values = np.array(df[features].tail(predict)) 
    df.dropna(inplace=True)
 
    predicted_val = df['predicted'].values
    features_dates = df[features + ['date']].values
    d = deque(maxlen=window)
    window_seq = []

    for i in range(len(features_dates)):
        d.append(features_dates[i])
        if len(d) == window:
            window_seq.append([np.array(d), predicted_val[i]])
    
    # final feature values left after broken up into window sequences, and last values 
    # len(last_values) = (window + predict)
    last_values = list([seq[:len(features)] for seq in d]) + list(last_values) 
    last_values = np.array(last_values).astype(np.float32)
    output['last values'] = last_values

    x, y = [], []
    for X, Y in window_seq:
        x.append(X)
        y.append(Y)

    x = np.array(x)
    y = np.array(y)

    output['x train'], output['x test'], output['y train'], output['y test'] = train_test_split(x, y, test_size=.2)

    dates = output['x test'][:, -1, -1]
    output['test df'] = output['original df'].loc[dates]
    # print(type(output['test df']))
    output['test df'] = output['test df'][~output['test df'].index.duplicated()]
    output['x train'] = output['x train'][:, :, : len(features)].astype(np.float32)
    output['x test'] = output['x test'][:, :, : len(features)].astype(np.float32)
    
    return output

# %%
get_data('AAPL')
# Out:
# (51, 5)
# (8219, 50, 5)
# (8219,)
# (2055, 50, 5)
# (2055,)
# {'original df':                   open        high         low       close    adjclose  \
#  1980-12-12    0.513400    0.515628    0.513400    0.513400    0.478481
#  1980-12-15    0.486614    0.488842    0.486614    0.486614    0.453517
#  1980-12-16    0.450900    0.453128    0.450900    0.450900    0.420232
#  1980-12-17    0.462057    0.464285    0.462057    0.462057    0.430630
#  1980-12-18    0.475457    0.477685    0.475457    0.475457    0.443119
#  ...                ...         ...         ...         ...         ...
#  2021-12-03  164.020004  164.960007  159.720001  161.839996  161.839996
#  2021-12-06  164.289993  167.879898  164.279999  165.320007  165.320007
#  2021-12-07  169.080002  171.580002  168.339996  171.179993  171.179993
#  2021-12-08  172.125000  175.960007  170.699997  175.080002  175.080002
#  2021-12-09  174.910004  176.750000  173.919998  174.559998  174.559998
#
#                   volume ticker
#  1980-12-12  117258400.0   AAPL
#  1980-12-15   43971200.0   AAPL
#  1980-12-16   26432000.0   AAPL
#  1980-12-17   21610400.0   AAPL
#  1980-12-18   18362400.0   AAPL
#  ...                 ...    ...
#  2021-12-03  118023116.0   AAPL
#  2021-12-06  107496982.0   AAPL
#  2021-12-07  120405352.0   AAPL
#  2021-12-08  116998901.0   AAPL
#  2021-12-09  108157647.0   AAPL
#
#  [10337 rows x 7 columns],
#  'scalers': {'adjclose': MinMaxScaler(),
#   'volume': MinMaxScaler(),
#   'open': MinMaxScaler(),
#   'high': MinMaxScaler(),
#   'low': MinMaxScaler()},
#  'last values': array([[0.44099286, 0.04024337, 0.43837664, 0.44024336, 0.43890065],
#         [0.4368811 , 0.04804078, 0.44204336, 0.44002363, 0.43657973],
#         [0.44043636, 0.05105243, 0.4366203 , 0.43557364, 0.42986497],
#         [0.42958504, 0.05303888, 0.4361889 , 0.43340668, 0.42726523],
#         [0.43567538, 0.04361974, 0.42919445, 0.43349823, 0.43063825],
#         [0.43842688, 0.04489285, 0.42913282, 0.43322352, 0.42757466],
#         [0.44241497, 0.0333011 , 0.44019458, 0.4395261 , 0.44103587],
#         [0.44120926, 0.03170463, 0.44318342, 0.43941352, 0.44054073],
#         [0.44093102, 0.03476814, 0.43776038, 0.44134215, 0.43821985],
#         [0.436912  , 0.03939851, 0.44071838, 0.43658084, 0.4358374 ],
#         [0.43505707, 0.04248781, 0.43457127, 0.43093443, 0.43014312],
#         [0.44386798, 0.03771073, 0.43726736, 0.43850368, 0.43729147],
#         [0.44720688, 0.03664977, 0.4423823 , 0.44160157, 0.44348052],
#         [0.4524934 , 0.04617028, 0.4413809 , 0.4475379 , 0.44239748],
#         [0.45932573, 0.04120187, 0.45236558, 0.45464933, 0.45288792],
#         [0.46087152, 0.03151346, 0.45757294, 0.45643148, 0.4577463 ],
#         [0.46155164, 0.03313297, 0.45791188, 0.4560838 , 0.45697266],
#         [0.45910934, 0.03176412, 0.4606234 , 0.45773193, 0.45935544],
#         [0.45895478, 0.02736073, 0.4575113 , 0.45525974, 0.45620242],
#         [0.46105704, 0.03284837, 0.45951417, 0.45974633, 0.46050075],
#         [0.45960402, 0.03025988, 0.4596066 , 0.4563585 , 0.4588913 ],
#         [0.47110456, 0.05398608, 0.461024  , 0.46684247, 0.46269754],
#         [0.46254098, 0.06740481, 0.45299724, 0.45699945, 0.45246333],
#         [0.45994407, 0.04023593, 0.45845112, 0.45626694, 0.45675606],
#         [0.4632211 , 0.03728721, 0.4574497 , 0.4619744 , 0.45938638],
#         [0.46776572, 0.02940573, 0.4627803 , 0.46319523, 0.46300703],
#         [0.46612716, 0.03257931, 0.46644703, 0.4645992 , 0.4655445 ],
#         [0.467799  , 0.03531387, 0.46740222, 0.4638972 , 0.46374968],
#         [0.46519834, 0.02968049, 0.46592322, 0.4619744 , 0.46405914],
#         [0.46634388, 0.03063371, 0.46219486, 0.46154097, 0.46375   ],
#         [0.45739624, 0.03516456, 0.46164024, 0.45757937, 0.4569108 ],
#         [0.45724145, 0.02211704, 0.4583741 , 0.45544285, 0.45638782],
#         [0.4638051 , 0.03441847, 0.45674098, 0.4584034 , 0.45576578],
#         [0.46383607, 0.03194718, 0.46271867, 0.46292055, 0.4618001 ],
#         [0.46693212, 0.0319652 , 0.46139374, 0.46172413, 0.46152163],
#         [0.47464135, 0.0479061 , 0.46464446, 0.4724431 , 0.4666276 ],
#         [0.48820207, 0.07434984, 0.47301015, 0.48364434, 0.4730023 ],
#         [0.49649954, 0.0632794 , 0.4851503 , 0.49081683, 0.48377994],
#         [0.4979547 , 0.06336695, 0.49756783, 0.50510067, 0.4976038 ],
#         [0.49916214, 0.0518089 , 0.49584234, 0.49319747, 0.49160072],
#         [0.50080305, 0.0374715 , 0.49470228, 0.49423516, 0.49339524],
#         [0.48492023, 0.04151521, 0.491051  , 0.4890771 , 0.4832452 ],
#         [0.49553975, 0.04787439, 0.4904501 , 0.49133566, 0.49076518],
#         [0.51120585, 0.09388859, 0.4923451 , 0.5045513 , 0.49426168],
#         [0.50956494, 0.07853837, 0.5154392 , 0.51914036, 0.50852746],
#         [0.50643784, 0.07376266, 0.4884935 , 0.5005225 , 0.48770133],
#         [0.5004934 , 0.06366646, 0.504778  , 0.5028421 , 0.4936428 ],
#         [0.5112678 , 0.05798823, 0.5056099 , 0.511754  , 0.50775385],
#         [0.52941066, 0.06495153, 0.5203693 , 0.5230471 , 0.5203176 ],
#         [0.5414853 , 0.06311396, 0.5297517 , 0.53641534, 0.5276207 ],
#         [0.5398753 , 0.05834462, 0.5383331 , 0.53882647, 0.5375851 ]],
#        dtype=float32),
#  'x train': array([[[2.1253630e-04, 3.5767067e-02, 2.2695720e-04, 2.1116006e-04,
#           2.2793343e-04],
#          [2.3186904e-04, 2.3194220e-02, 2.4760177e-04, 2.3160921e-04,
#           2.4866677e-04],
#          [2.3830090e-04, 2.5731748e-02, 2.5446992e-04, 2.2480913e-04,
#           2.5556449e-04],
#          ...,
#          [1.8677484e-04, 5.9360042e-03, 1.9944760e-04, 1.8391083e-04,
#           2.0030550e-04],
#          [2.0610739e-04, 4.8092208e-03, 2.2009216e-04, 1.9075675e-04,
#           2.2103885e-04],
#          [2.1253630e-04, 5.7879817e-03, 2.2695720e-04, 1.9755682e-04,
#           2.2793343e-04]],
#
#         [[4.2316899e-01, 2.8312961e-02, 4.2028958e-01, 4.1851237e-01,
#           4.1949797e-01],
#          [4.3147284e-01, 4.2586446e-02, 4.2429519e-01, 4.2666149e-01,
#           4.2564058e-01],
#          [4.3783185e-01, 5.8357649e-02, 4.3098161e-01, 4.3627563e-01,
#           4.3283540e-01],
#          ...,
#          [4.7895709e-01, 4.0145282e-02, 4.8308587e-01, 4.7866940e-01,
#           4.7586477e-01],
#          [4.7574189e-01, 3.0913036e-02, 4.7849479e-01, 4.7583097e-01,
#           4.7578737e-01],
#          [4.5997497e-01, 7.6003529e-02, 4.7698495e-01, 4.7390813e-01,
#           4.5954111e-01]],
#
#         [[1.4307773e-01, 2.5367016e-01, 1.4334926e-01, 1.4968815e-01,
#           1.4350167e-01],
#          [1.4231445e-01, 1.5314837e-01, 1.5282637e-01, 1.5136136e-01,
#           1.4831145e-01],
#          [1.3971679e-01, 1.0313958e-01, 1.4736812e-01, 1.4687040e-01,
#           1.4532302e-01],
#          ...,
#          [1.4766996e-01, 6.0575292e-02, 1.5262829e-01, 1.5286997e-01,
#           1.5279408e-01],
#          [1.4720611e-01, 4.1718937e-02, 1.5485120e-01, 1.5385537e-01,
#           1.5430599e-01],
#          [1.4742541e-01, 4.7592122e-02, 1.5239058e-01, 1.5239036e-01,
#           1.5236969e-01]],
#
#         ...,
#
#         [[4.1864315e-04, 3.2111818e-03, 4.4704942e-04, 4.2236596e-04,
#           4.4897234e-04],
#          [3.4778487e-04, 3.1507646e-03, 3.7138263e-04, 3.4741536e-04,
#           3.7298008e-04],
#          [3.5421379e-04, 3.3169123e-03, 3.7824767e-04, 3.5426128e-04,
#           3.7987466e-04],
#          ...,
#          [3.4778487e-04, 5.6308964e-03, 3.7138263e-04, 3.4741536e-04,
#           3.7298008e-04],
#          [3.9287927e-04, 3.4679556e-03, 4.1953669e-04, 3.9511675e-04,
#           4.2134128e-04],
#          [4.5726553e-04, 6.2985085e-03, 4.8829225e-04, 4.7006735e-04,
#           4.9039256e-04]],
#
#         [[1.1528757e-03, 2.4737881e-02, 1.2311005e-03, 1.1921960e-03,
#           1.1397137e-03],
#          [1.1915399e-03, 3.3009019e-02, 1.2723895e-03, 1.2398945e-03,
#           1.2294982e-03],
#          [1.2816923e-03, 6.1462566e-02, 1.3686578e-03, 1.3420974e-03,
#           1.2778626e-03],
#          ...,
#          [1.1593449e-03, 1.8309476e-02, 1.2380087e-03, 1.2126453e-03,
#           1.2226036e-03],
#          [1.1593449e-03, 2.0481480e-02, 1.2380087e-03, 1.2194453e-03,
#           1.2294982e-03],
#          [1.1206784e-03, 2.0091789e-02, 1.1967197e-03, 1.1990389e-03,
#           1.2018671e-03]],
#
#         [[8.2838319e-02, 9.2349634e-02, 8.3572589e-02, 8.5767195e-02,
#           8.3516508e-02],
#          [8.2260571e-02, 6.6036783e-02, 8.7287717e-02, 8.6438656e-02,
#           8.6084962e-02],
#          [8.1518427e-02, 5.7959318e-02, 8.6433768e-02, 8.5697435e-02,
#           8.4895782e-02],
#          ...,
#          [8.5000783e-02, 5.7022166e-02, 8.8141672e-02, 8.8265568e-02,
#           8.8206924e-02],
#          [8.4470302e-02, 5.6065932e-02, 8.8238515e-02, 8.7964714e-02,
#           8.8290922e-02],
#          [8.3941489e-02, 5.2706674e-02, 8.8498220e-02, 8.7659508e-02,
#           8.7442137e-02]]], dtype=float32),
#  'x test': array([[[0.07989067, 0.03886009, 0.08344933, 0.08286769, 0.08322032],
#          [0.07955753, 0.0469338 , 0.08329527, 0.08271945, 0.08324685],
#          [0.08009309, 0.05067647, 0.08396875, 0.08322087, 0.08348115],
#          ...,
#          [0.08033346, 0.05243851, 0.08516604, 0.08438939, 0.08382154],
#          [0.0818389 , 0.08209882, 0.08438692, 0.08460871, 0.08452886],
#          [0.08301965, 0.08258463, 0.08566345, 0.08646046, 0.08588603]],
#
#         [[0.00177938, 0.01100049, 0.00183525, 0.00180545, 0.00183076],
#          [0.00176589, 0.0115231 , 0.00182292, 0.00180545, 0.00183076],
#          [0.00202312, 0.07272285, 0.00186606, 0.00206445, 0.00181662],
#          ...,
#          [0.00206234, 0.02586316, 0.00215218, 0.00213246, 0.00213447],
#          [0.00206234, 0.01916891, 0.00213898, 0.00211895, 0.00214818],
#          [0.00207583, 0.03093519, 0.00206855, 0.00213246, 0.00203766]],
#
#         [[0.00494843, 0.0548514 , 0.00529068, 0.00523907, 0.00503581],
#          [0.00504753, 0.03088988, 0.00522025, 0.00522556, 0.00520822],
#          [0.00479704, 0.04736116, 0.00520704, 0.00514359, 0.00500796],
#          ...,
#          [0.00571297, 0.19082214, 0.00615783, 0.00612462, 0.0057334 ],
#          [0.00565351, 0.08864131, 0.00601697, 0.00604309, 0.00579529],
#          [0.00579831, 0.12246143, 0.00594214, 0.00636312, 0.00593344]],
#
#         ...,
#
#         [[0.00125593, 0.00749477, 0.00134115, 0.00130804, 0.00134691],
#          [0.00128169, 0.01256379, 0.00136866, 0.00133529, 0.00137454],
#          [0.00123663, 0.00928917, 0.00132054, 0.0012876 , 0.00132622],
#          ...,
#          [0.00076   , 0.00072501, 0.00081156, 0.00078343, 0.00081505],
#          [0.00074714, 0.00156481, 0.00079783, 0.00077663, 0.00080126],
#          [0.00064408, 0.00206627, 0.00068778, 0.00066082, 0.00069074]],
#
#         [[0.32704327, 0.0184186 , 0.32945368, 0.3316494 , 0.3291069 ],
#          [0.31882498, 0.02760614, 0.33127162, 0.32841107, 0.3214634 ],
#          [0.323055  , 0.01740479, 0.32775897, 0.32801738, 0.32789785],
#          ...,
#          [0.36224332, 0.01189478, 0.36914045, 0.36809155, 0.3700165 ],
#          [0.3619109 , 0.01252098, 0.3677539 , 0.36592454, 0.36918098],
#          [0.36768192, 0.01757857, 0.37043458, 0.37202877, 0.37159473]],
#
#         [[0.01616809, 0.07974716, 0.01675301, 0.01680264, 0.0166394 ],
#          [0.01620183, 0.05333844, 0.01677502, 0.0167852 , 0.0167676 ],
#          [0.01660666, 0.06997824, 0.0169687 , 0.01721685, 0.01653772],
#          ...,
#          [0.01745426, 0.04213933, 0.01812637, 0.01814993, 0.01798772],
#          [0.01763982, 0.04003209, 0.01826723, 0.01833305, 0.01822202],
#          [0.01765246, 0.03323171, 0.01839929, 0.01825021, 0.01829276]]],
#        dtype=float32),
#  'y train': array([2.12536295e-04, 4.61768088e-01, 1.46442828e-01, ...,
#         4.76598839e-04, 1.11425026e-03, 8.25258568e-02]),
#  'y test': array([0.08391786, 0.00206234, 0.00593351, ..., 0.00058608, 0.36786319,
#         0.0174374 ]),
#  'test df':                   open        high         low       close    adjclose  \
#  2009-12-21   28.000000   28.535713   27.952856   28.318571   26.999752
#  1996-12-06    0.870000    0.906285    0.857142    0.897428    0.855634
#  1999-09-30    2.127142    2.292428    2.116071    2.158482    2.057960
#  1998-09-18    1.288571    1.312571    1.263428    1.312571    1.251444
#  2006-11-21   12.488571   12.657142   12.444285   12.657142   12.067687
#  ...                ...         ...         ...         ...         ...
#  1999-10-15    2.540000    2.707714    2.506714    2.663000    2.538982
#  2013-03-21   64.317139   65.425713   64.300003   64.675713   61.889587
#  1981-03-09    0.421885    0.424114    0.421885    0.421885    0.393191
#  2017-01-25  120.419998  122.099998  120.279999  121.879997  118.943085
#  2005-08-03    6.170000    6.187142    6.110000    6.174285    5.886743
#
#                   volume ticker
#  2009-12-21  153093108.0   AAPL
#  1996-12-06   57346800.0   AAPL
#  1999-09-30  227015600.0   AAPL
#  1998-09-18   76269200.0   AAPL
#  2006-11-21  154610869.0   AAPL
#  ...                 ...    ...
#  1999-10-15  293294400.0   AAPL
#  2013-03-21   95813410.0   AAPL
#  1981-03-09    3830400.0   AAPL
#  2017-01-25   32586673.0   AAPL
#  2005-08-03   61604025.0   AAPL
#
#  [2055 rows x 7 columns]}

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
import pandas as pd

# %%
def make_LSTM_model(window_seq_length, num_features, num_layers=4, units=45, dropout=0.2):
    rnn = Sequential()
    for layer in range(num_layers):
        if layer == 0:
            rnn.add(LSTM(units, return_sequences=True, input_shape=(window_seq_length, num_features)))
        elif layer == num_layers -1:
            rnn.add(LSTM(units))
        else:
            rnn.add(LSTM(units, return_sequences=True))
        rnn.add(Dropout(dropout))
    rnn.add(Dense(units=1))
    rnn.compile(optimizer='adam', metrics='mean_absolute_error', loss='huber_loss')
    return rnn

# %%
import os
import time

# %%
ticker = 'AMZN'
window = 50
predict = 1
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 77/77 [==============================] - ETA: 0s - loss: 0.0020 - mean_absolute_error: 0.0250
# Epoch 00001: val_loss improved from inf to 0.00011, saving model to model_checkpoint/2021-12-10_AMZN.h5
# 77/77 [==============================] - 49s 558ms/step - loss: 0.0020 - mean_absolute_error: 0.0250 - val_loss: 1.0804e-04 - val_mean_absolute_error: 0.0075
# Epoch 2/10
# 77/77 [==============================] - ETA: 0s - loss: 2.6387e-04 - mean_absolute_error: 0.0107
# Epoch 00002: val_loss improved from 0.00011 to 0.00007, saving model to model_checkpoint/2021-12-10_AMZN.h5
# 77/77 [==============================] - 42s 546ms/step - loss: 2.6387e-04 - mean_absolute_error: 0.0107 - val_loss: 6.8359e-05 - val_mean_absolute_error: 0.0053
# Epoch 3/10
# 77/77 [==============================] - ETA: 0s - loss: 3.3093e-04 - mean_absolute_error: 0.0118
# Epoch 00003: val_loss did not improve from 0.00007
# 77/77 [==============================] - 41s 529ms/step - loss: 3.3093e-04 - mean_absolute_error: 0.0118 - val_loss: 6.9108e-05 - val_mean_absolute_error: 0.0053
# Epoch 4/10
# 77/77 [==============================] - ETA: 0s - loss: 2.6140e-04 - mean_absolute_error: 0.0105
# Epoch 00004: val_loss did not improve from 0.00007
# 77/77 [==============================] - 41s 531ms/step - loss: 2.6140e-04 - mean_absolute_error: 0.0105 - val_loss: 4.9022e-04 - val_mean_absolute_error: 0.0154
# Epoch 5/10
# 77/77 [==============================] - ETA: 0s - loss: 3.4037e-04 - mean_absolute_error: 0.0121
# Epoch 00005: val_loss improved from 0.00007 to 0.00007, saving model to model_checkpoint/2021-12-10_AMZN.h5
# 77/77 [==============================] - 43s 561ms/step - loss: 3.4037e-04 - mean_absolute_error: 0.0121 - val_loss: 6.7073e-05 - val_mean_absolute_error: 0.0056
# Epoch 6/10
# 77/77 [==============================] - ETA: 0s - loss: 2.2200e-04 - mean_absolute_error: 0.0102
# Epoch 00006: val_loss improved from 0.00007 to 0.00006, saving model to model_checkpoint/2021-12-10_AMZN.h5
# 77/77 [==============================] - 39s 503ms/step - loss: 2.2200e-04 - mean_absolute_error: 0.0102 - val_loss: 6.1073e-05 - val_mean_absolute_error: 0.0049
# Epoch 7/10
# 77/77 [==============================] - ETA: 0s - loss: 4.0661e-04 - mean_absolute_error: 0.0134
# Epoch 00007: val_loss did not improve from 0.00006
# 77/77 [==============================] - 39s 503ms/step - loss: 4.0661e-04 - mean_absolute_error: 0.0134 - val_loss: 1.1702e-04 - val_mean_absolute_error: 0.0078
# Epoch 8/10
# 77/77 [==============================] - ETA: 0s - loss: 1.8725e-04 - mean_absolute_error: 0.0099
# Epoch 00008: val_loss did not improve from 0.00006
# 77/77 [==============================] - 38s 496ms/step - loss: 1.8725e-04 - mean_absolute_error: 0.0099 - val_loss: 1.7823e-04 - val_mean_absolute_error: 0.0104
# Epoch 9/10
# 77/77 [==============================] - ETA: 0s - loss: 2.7261e-04 - mean_absolute_error: 0.0112
# Epoch 00009: val_loss did not improve from 0.00006
# 77/77 [==============================] - 38s 493ms/step - loss: 2.7261e-04 - mean_absolute_error: 0.0112 - val_loss: 9.3535e-05 - val_mean_absolute_error: 0.0066
# Epoch 10/10
# 77/77 [==============================] - ETA: 0s - loss: 2.1276e-04 - mean_absolute_error: 0.0103
# Epoch 00010: val_loss did not improve from 0.00006
# 77/77 [==============================] - 38s 496ms/step - loss: 2.1276e-04 - mean_absolute_error: 0.0103 - val_loss: 1.2405e-04 - val_mean_absolute_error: 0.0078

# %%
os.mkdir('tensorboard')
os.mkdir('model_checkpoint')
os.mkdir('data')

# %%
import matplotlib.pyplot as plt

# %%
def make_prediction(m, d):
    last_values = d['last values'][-window:]
    last_values = np.expand_dims(last_values, 0)
    print(np.shape(last_values))
    prediction = m.predict(last_values)
    predicted_price = d['scalers']['adjclose'].inverse_transform(prediction)[0][0]
    return predicted_price

# %%
def get_finished_df(m, d):
    x_test = d['x test']
    y_test = d['y test']

    y_prediction = m.predict(x_test)
    y_test = np.squeeze(d['scalers']['adjclose'].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_prediction = np.squeeze(d['scalers']['adjclose'].inverse_transform(y_prediction))
    
    test_df = d['test df']

    test_df[f'actual adjclose {predict}'] = y_test
    test_df[f'adjclose {predict}'] = y_prediction
    test_df.sort_index(inplace=True)
    finished_df = test_df
    
    return finished_df

# %%
def plot(df):
    plt.plot(df[f'actual adjclose {predict}'], c='b')
    plt.plot(df[f'adjclose {predict}'], c='r')
    plt.xlabel('Days')
    plt.ylabel('Price')
    plt.legend(['Actual Price', 'Predicted Price'])
    plt.show()

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)

# %%
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
# Out:
# 39/39 [==============================] - 3s 86ms/step - loss: 6.1073e-05 - mean_absolute_error: 0.0049

# %%
print(type(data['test df']))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)
# Out:
# (1, 50, 5)
# Future price after 1 days is 3557.92$
# Loss: 6.107318768044934e-05
# Mean absolute error: 19.610782351977047

# %%
csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)

# %%
ticker = 'AAPL'
window = 50
predict = 7
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 129/129 [==============================] - ETA: 0s - loss: 0.0013 - mean_absolute_error: 0.0213
# Epoch 00001: val_loss improved from inf to 0.00036, saving model to model_checkpoint/2021-12-10_AAPL.h5
# 129/129 [==============================] - 72s 510ms/step - loss: 0.0013 - mean_absolute_error: 0.0213 - val_loss: 3.6250e-04 - val_mean_absolute_error: 0.0092
# Epoch 2/10
# 129/129 [==============================] - ETA: 0s - loss: 6.5195e-04 - mean_absolute_error: 0.0161
# Epoch 00002: val_loss did not improve from 0.00036
# 129/129 [==============================] - 67s 519ms/step - loss: 6.5195e-04 - mean_absolute_error: 0.0161 - val_loss: 3.8283e-04 - val_mean_absolute_error: 0.0096
# Epoch 3/10
# 129/129 [==============================] - ETA: 0s - loss: 7.2061e-04 - mean_absolute_error: 0.0168
# Epoch 00003: val_loss did not improve from 0.00036
# 129/129 [==============================] - 69s 537ms/step - loss: 7.2061e-04 - mean_absolute_error: 0.0168 - val_loss: 5.4339e-04 - val_mean_absolute_error: 0.0147
# Epoch 4/10
# 129/129 [==============================] - ETA: 0s - loss: 6.0456e-04 - mean_absolute_error: 0.0159
# Epoch 00004: val_loss improved from 0.00036 to 0.00030, saving model to model_checkpoint/2021-12-10_AAPL.h5
# 129/129 [==============================] - 63s 489ms/step - loss: 6.0456e-04 - mean_absolute_error: 0.0159 - val_loss: 2.9869e-04 - val_mean_absolute_error: 0.0083
# Epoch 5/10
# 129/129 [==============================] - ETA: 0s - loss: 4.5888e-04 - mean_absolute_error: 0.0138
# Epoch 00005: val_loss did not improve from 0.00030
# 129/129 [==============================] - 67s 523ms/step - loss: 4.5888e-04 - mean_absolute_error: 0.0138 - val_loss: 3.6391e-04 - val_mean_absolute_error: 0.0112
# Epoch 6/10
# 129/129 [==============================] - ETA: 0s - loss: 5.2315e-04 - mean_absolute_error: 0.0144
# Epoch 00006: val_loss did not improve from 0.00030
# 129/129 [==============================] - 64s 495ms/step - loss: 5.2315e-04 - mean_absolute_error: 0.0144 - val_loss: 2.9878e-04 - val_mean_absolute_error: 0.0083
# Epoch 7/10
# 129/129 [==============================] - ETA: 0s - loss: 5.5049e-04 - mean_absolute_error: 0.0154
# Epoch 00007: val_loss improved from 0.00030 to 0.00029, saving model to model_checkpoint/2021-12-10_AAPL.h5
# 129/129 [==============================] - 63s 486ms/step - loss: 5.5049e-04 - mean_absolute_error: 0.0154 - val_loss: 2.9084e-04 - val_mean_absolute_error: 0.0065
# Epoch 8/10
# 129/129 [==============================] - ETA: 0s - loss: 4.2650e-04 - mean_absolute_error: 0.0137
# Epoch 00008: val_loss did not improve from 0.00029
# 129/129 [==============================] - 62s 478ms/step - loss: 4.2650e-04 - mean_absolute_error: 0.0137 - val_loss: 3.4774e-04 - val_mean_absolute_error: 0.0093
# Epoch 9/10
# 129/129 [==============================] - ETA: 0s - loss: 5.4267e-04 - mean_absolute_error: 0.0153
# Epoch 00009: val_loss did not improve from 0.00029
# 129/129 [==============================] - 62s 477ms/step - loss: 5.4267e-04 - mean_absolute_error: 0.0153 - val_loss: 4.5324e-04 - val_mean_absolute_error: 0.0140
# Epoch 10/10
# 129/129 [==============================] - ETA: 0s - loss: 4.0573e-04 - mean_absolute_error: 0.0135
# Epoch 00010: val_loss did not improve from 0.00029
# 129/129 [==============================] - 64s 495ms/step - loss: 4.0573e-04 - mean_absolute_error: 0.0135 - val_loss: 3.1096e-04 - val_mean_absolute_error: 0.0116

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 65/65 [==============================] - 5s 72ms/step - loss: 2.9084e-04 - mean_absolute_error: 0.0065
# (1, 50, 5)
# Future price after 7 days is 164.11$
# Loss: 0.0002908439782913774
# Mean absolute error: 2.2731914387669265

# %%
ticker = 'BLK'
window = 50
predict = 7
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 70/70 [==============================] - ETA: 0s - loss: 0.0056 - mean_absolute_error: 0.0525
# Epoch 00001: val_loss improved from inf to 0.00025, saving model to model_checkpoint/2021-12-10_BLK.h5
# 70/70 [==============================] - 44s 520ms/step - loss: 0.0056 - mean_absolute_error: 0.0525 - val_loss: 2.4791e-04 - val_mean_absolute_error: 0.0143
# Epoch 2/10
# 70/70 [==============================] - ETA: 0s - loss: 3.9104e-04 - mean_absolute_error: 0.0171
# Epoch 00002: val_loss did not improve from 0.00025
# 70/70 [==============================] - 41s 585ms/step - loss: 3.9104e-04 - mean_absolute_error: 0.0171 - val_loss: 9.0936e-04 - val_mean_absolute_error: 0.0287
# Epoch 3/10
# 70/70 [==============================] - ETA: 0s - loss: 4.3010e-04 - mean_absolute_error: 0.0183
# Epoch 00003: val_loss did not improve from 0.00025
# 70/70 [==============================] - 40s 572ms/step - loss: 4.3010e-04 - mean_absolute_error: 0.0183 - val_loss: 2.8999e-04 - val_mean_absolute_error: 0.0181
# Epoch 4/10
# 70/70 [==============================] - ETA: 0s - loss: 3.2181e-04 - mean_absolute_error: 0.0160
# Epoch 00004: val_loss improved from 0.00025 to 0.00024, saving model to model_checkpoint/2021-12-10_BLK.h5
# 70/70 [==============================] - 38s 547ms/step - loss: 3.2181e-04 - mean_absolute_error: 0.0160 - val_loss: 2.3950e-04 - val_mean_absolute_error: 0.0136
# Epoch 5/10
# 70/70 [==============================] - ETA: 0s - loss: 3.9125e-04 - mean_absolute_error: 0.0173
# Epoch 00005: val_loss did not improve from 0.00024
# 70/70 [==============================] - 36s 514ms/step - loss: 3.9125e-04 - mean_absolute_error: 0.0173 - val_loss: 4.8993e-04 - val_mean_absolute_error: 0.0204
# Epoch 6/10
# 70/70 [==============================] - ETA: 0s - loss: 4.3585e-04 - mean_absolute_error: 0.0186
# Epoch 00006: val_loss did not improve from 0.00024
# 70/70 [==============================] - 38s 539ms/step - loss: 4.3585e-04 - mean_absolute_error: 0.0186 - val_loss: 4.1764e-04 - val_mean_absolute_error: 0.0171
# Epoch 7/10
# 70/70 [==============================] - ETA: 0s - loss: 4.4013e-04 - mean_absolute_error: 0.0182
# Epoch 00007: val_loss did not improve from 0.00024
# 70/70 [==============================] - 36s 516ms/step - loss: 4.4013e-04 - mean_absolute_error: 0.0182 - val_loss: 4.3790e-04 - val_mean_absolute_error: 0.0185
# Epoch 8/10
# 70/70 [==============================] - ETA: 0s - loss: 3.1539e-04 - mean_absolute_error: 0.0157
# Epoch 00008: val_loss improved from 0.00024 to 0.00019, saving model to model_checkpoint/2021-12-10_BLK.h5
# 70/70 [==============================] - 39s 553ms/step - loss: 3.1539e-04 - mean_absolute_error: 0.0157 - val_loss: 1.8529e-04 - val_mean_absolute_error: 0.0113
# Epoch 9/10
# 70/70 [==============================] - ETA: 0s - loss: 2.6630e-04 - mean_absolute_error: 0.0140
# Epoch 00009: val_loss did not improve from 0.00019
# 70/70 [==============================] - 34s 486ms/step - loss: 2.6630e-04 - mean_absolute_error: 0.0140 - val_loss: 2.4759e-04 - val_mean_absolute_error: 0.0145
# Epoch 10/10
# 70/70 [==============================] - ETA: 0s - loss: 2.7786e-04 - mean_absolute_error: 0.0146
# Epoch 00010: val_loss did not improve from 0.00019
# 70/70 [==============================] - 33s 472ms/step - loss: 2.7786e-04 - mean_absolute_error: 0.0146 - val_loss: 1.9029e-04 - val_mean_absolute_error: 0.0118

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 35/35 [==============================] - 3s 83ms/step - loss: 1.8529e-04 - mean_absolute_error: 0.0113
# (1, 50, 5)
# Future price after 7 days is 918.58$
# Loss: 0.00018528985674493015
# Mean absolute error: 19.254658405068692

# %%
ticker = 'CHTR'
window = 50
predict = 1
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 37/37 [==============================] - ETA: 0s - loss: 0.0209 - mean_absolute_error: 0.1122
# Epoch 00001: val_loss improved from inf to 0.00037, saving model to model_checkpoint/2021-12-10_CHTR.h5
# 37/37 [==============================] - 28s 574ms/step - loss: 0.0209 - mean_absolute_error: 0.1122 - val_loss: 3.6745e-04 - val_mean_absolute_error: 0.0222
# Epoch 2/10
# 37/37 [==============================] - ETA: 0s - loss: 6.0156e-04 - mean_absolute_error: 0.0237
# Epoch 00002: val_loss improved from 0.00037 to 0.00020, saving model to model_checkpoint/2021-12-10_CHTR.h5
# 37/37 [==============================] - 22s 588ms/step - loss: 6.0156e-04 - mean_absolute_error: 0.0237 - val_loss: 1.9806e-04 - val_mean_absolute_error: 0.0129
# Epoch 3/10
# 37/37 [==============================] - ETA: 0s - loss: 4.7547e-04 - mean_absolute_error: 0.0196
# Epoch 00003: val_loss did not improve from 0.00020
# 37/37 [==============================] - 20s 544ms/step - loss: 4.7547e-04 - mean_absolute_error: 0.0196 - val_loss: 2.2195e-04 - val_mean_absolute_error: 0.0142
# Epoch 4/10
# 37/37 [==============================] - ETA: 0s - loss: 3.9472e-04 - mean_absolute_error: 0.0183
# Epoch 00004: val_loss did not improve from 0.00020
# 37/37 [==============================] - 21s 577ms/step - loss: 3.9472e-04 - mean_absolute_error: 0.0183 - val_loss: 2.1021e-04 - val_mean_absolute_error: 0.0136
# Epoch 5/10
# 37/37 [==============================] - ETA: 0s - loss: 4.0737e-04 - mean_absolute_error: 0.0180
# Epoch 00005: val_loss did not improve from 0.00020
# 37/37 [==============================] - 21s 554ms/step - loss: 4.0737e-04 - mean_absolute_error: 0.0180 - val_loss: 3.5695e-04 - val_mean_absolute_error: 0.0179
# Epoch 6/10
# 37/37 [==============================] - ETA: 0s - loss: 4.0887e-04 - mean_absolute_error: 0.0182
# Epoch 00006: val_loss improved from 0.00020 to 0.00016, saving model to model_checkpoint/2021-12-10_CHTR.h5
# 37/37 [==============================] - 20s 556ms/step - loss: 4.0887e-04 - mean_absolute_error: 0.0182 - val_loss: 1.6430e-04 - val_mean_absolute_error: 0.0117
# Epoch 7/10
# 37/37 [==============================] - ETA: 0s - loss: 3.7030e-04 - mean_absolute_error: 0.0170
# Epoch 00007: val_loss did not improve from 0.00016
# 37/37 [==============================] - 23s 617ms/step - loss: 3.7030e-04 - mean_absolute_error: 0.0170 - val_loss: 1.8730e-04 - val_mean_absolute_error: 0.0130
# Epoch 8/10
# 37/37 [==============================] - ETA: 0s - loss: 3.9067e-04 - mean_absolute_error: 0.0176
# Epoch 00008: val_loss did not improve from 0.00016
# 37/37 [==============================] - 23s 621ms/step - loss: 3.9067e-04 - mean_absolute_error: 0.0176 - val_loss: 1.7655e-04 - val_mean_absolute_error: 0.0122
# Epoch 9/10
# 37/37 [==============================] - ETA: 0s - loss: 3.5807e-04 - mean_absolute_error: 0.0168
# Epoch 00009: val_loss improved from 0.00016 to 0.00016, saving model to model_checkpoint/2021-12-10_CHTR.h5
# 37/37 [==============================] - 22s 586ms/step - loss: 3.5807e-04 - mean_absolute_error: 0.0168 - val_loss: 1.6157e-04 - val_mean_absolute_error: 0.0120
# Epoch 10/10
# 37/37 [==============================] - ETA: 0s - loss: 3.5768e-04 - mean_absolute_error: 0.0171
# Epoch 00010: val_loss did not improve from 0.00016
# 37/37 [==============================] - 19s 514ms/step - loss: 3.5768e-04 - mean_absolute_error: 0.0171 - val_loss: 1.6991e-04 - val_mean_absolute_error: 0.0118

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 19/19 [==============================] - 1s 72ms/step - loss: 1.6157e-04 - mean_absolute_error: 0.0120
# (1, 50, 5)
# Future price after 1 days is 669.30$
# Loss: 0.00016157182108145207
# Mean absolute error: 42.056593747929746

# %%
ticker = 'TMO'
window = 50
predict = 1
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 131/131 [==============================] - ETA: 0s - loss: 9.6291e-04 - mean_absolute_error: 0.0167
# Epoch 00001: val_loss improved from inf to 0.00003, saving model to model_checkpoint/2021-12-10_TMO.h5
# 131/131 [==============================] - 79s 548ms/step - loss: 9.6291e-04 - mean_absolute_error: 0.0167 - val_loss: 3.0768e-05 - val_mean_absolute_error: 0.0034
# Epoch 2/10
# 131/131 [==============================] - ETA: 0s - loss: 1.5873e-04 - mean_absolute_error: 0.0081
# Epoch 00002: val_loss did not improve from 0.00003
# 131/131 [==============================] - 77s 585ms/step - loss: 1.5873e-04 - mean_absolute_error: 0.0081 - val_loss: 4.4484e-05 - val_mean_absolute_error: 0.0044
# Epoch 3/10
# 131/131 [==============================] - ETA: 0s - loss: 1.2337e-04 - mean_absolute_error: 0.0073
# Epoch 00003: val_loss did not improve from 0.00003
# 131/131 [==============================] - 76s 577ms/step - loss: 1.2337e-04 - mean_absolute_error: 0.0073 - val_loss: 1.0677e-04 - val_mean_absolute_error: 0.0077
# Epoch 4/10
# 131/131 [==============================] - ETA: 0s - loss: 1.8234e-04 - mean_absolute_error: 0.0091
# Epoch 00004: val_loss did not improve from 0.00003
# 131/131 [==============================] - 72s 548ms/step - loss: 1.8234e-04 - mean_absolute_error: 0.0091 - val_loss: 8.6881e-05 - val_mean_absolute_error: 0.0060
# Epoch 5/10
# 131/131 [==============================] - ETA: 0s - loss: 1.2100e-04 - mean_absolute_error: 0.0073
# Epoch 00005: val_loss did not improve from 0.00003
# 131/131 [==============================] - 68s 520ms/step - loss: 1.2100e-04 - mean_absolute_error: 0.0073 - val_loss: 5.9826e-05 - val_mean_absolute_error: 0.0049
# Epoch 6/10
# 131/131 [==============================] - ETA: 0s - loss: 1.7769e-04 - mean_absolute_error: 0.0087
# Epoch 00006: val_loss did not improve from 0.00003
# 131/131 [==============================] - 66s 502ms/step - loss: 1.7769e-04 - mean_absolute_error: 0.0087 - val_loss: 3.5464e-05 - val_mean_absolute_error: 0.0039
# Epoch 7/10
# 131/131 [==============================] - ETA: 0s - loss: 9.0712e-05 - mean_absolute_error: 0.0070
# Epoch 00007: val_loss improved from 0.00003 to 0.00003, saving model to model_checkpoint/2021-12-10_TMO.h5
# 131/131 [==============================] - 64s 488ms/step - loss: 9.0712e-05 - mean_absolute_error: 0.0070 - val_loss: 2.8692e-05 - val_mean_absolute_error: 0.0043
# Epoch 8/10
# 131/131 [==============================] - ETA: 0s - loss: 1.0282e-04 - mean_absolute_error: 0.0072
# Epoch 00008: val_loss did not improve from 0.00003
# 131/131 [==============================] - 65s 493ms/step - loss: 1.0282e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8399e-04 - val_mean_absolute_error: 0.0092
# Epoch 9/10
# 131/131 [==============================] - ETA: 0s - loss: 2.0176e-04 - mean_absolute_error: 0.0097
# Epoch 00009: val_loss improved from 0.00003 to 0.00002, saving model to model_checkpoint/2021-12-10_TMO.h5
# 131/131 [==============================] - 64s 490ms/step - loss: 2.0176e-04 - mean_absolute_error: 0.0097 - val_loss: 2.2701e-05 - val_mean_absolute_error: 0.0028
# Epoch 10/10
# 131/131 [==============================] - ETA: 0s - loss: 9.3824e-05 - mean_absolute_error: 0.0075
# Epoch 00010: val_loss did not improve from 0.00002
# 131/131 [==============================] - 64s 487ms/step - loss: 9.3824e-05 - mean_absolute_error: 0.0075 - val_loss: 3.3150e-05 - val_mean_absolute_error: 0.0047

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 66/66 [==============================] - 8s 123ms/step - loss: 2.2701e-05 - mean_absolute_error: 0.0028
# (1, 50, 5)
# Future price after 1 days is 645.80$
# Loss: 2.2700580302625895e-05
# Mean absolute error: 2.6394335117696905

# %%
ticker = 'UAL'
window = 50
predict = 1
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 50/50 [==============================] - ETA: 0s - loss: 0.0171 - mean_absolute_error: 0.1117
# Epoch 00001: val_loss improved from inf to 0.00093, saving model to model_checkpoint/2021-12-10_UAL.h5
# 50/50 [==============================] - 39s 572ms/step - loss: 0.0171 - mean_absolute_error: 0.1117 - val_loss: 9.3168e-04 - val_mean_absolute_error: 0.0322
# Epoch 2/10
# 50/50 [==============================] - ETA: 0s - loss: 0.0014 - mean_absolute_error: 0.0376
# Epoch 00002: val_loss did not improve from 0.00093
# 50/50 [==============================] - 29s 584ms/step - loss: 0.0014 - mean_absolute_error: 0.0376 - val_loss: 0.0019 - val_mean_absolute_error: 0.0459
# Epoch 3/10
# 50/50 [==============================] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0346
# Epoch 00003: val_loss improved from 0.00093 to 0.00065, saving model to model_checkpoint/2021-12-10_UAL.h5
# 50/50 [==============================] - 27s 529ms/step - loss: 0.0012 - mean_absolute_error: 0.0346 - val_loss: 6.5068e-04 - val_mean_absolute_error: 0.0261
# Epoch 4/10
# 50/50 [==============================] - ETA: 0s - loss: 0.0011 - mean_absolute_error: 0.0333
# Epoch 00004: val_loss did not improve from 0.00065
# 50/50 [==============================] - 24s 487ms/step - loss: 0.0011 - mean_absolute_error: 0.0333 - val_loss: 7.1151e-04 - val_mean_absolute_error: 0.0277
# Epoch 5/10
# 50/50 [==============================] - ETA: 0s - loss: 0.0010 - mean_absolute_error: 0.0322
# Epoch 00005: val_loss improved from 0.00065 to 0.00062, saving model to model_checkpoint/2021-12-10_UAL.h5
# 50/50 [==============================] - 25s 503ms/step - loss: 0.0010 - mean_absolute_error: 0.0322 - val_loss: 6.2104e-04 - val_mean_absolute_error: 0.0252
# Epoch 6/10
# 50/50 [==============================] - ETA: 0s - loss: 0.0010 - mean_absolute_error: 0.0321
# Epoch 00006: val_loss improved from 0.00062 to 0.00060, saving model to model_checkpoint/2021-12-10_UAL.h5
# 50/50 [==============================] - 25s 491ms/step - loss: 0.0010 - mean_absolute_error: 0.0321 - val_loss: 5.9733e-04 - val_mean_absolute_error: 0.0258
# Epoch 7/10
# 50/50 [==============================] - ETA: 0s - loss: 9.0251e-04 - mean_absolute_error: 0.0305
# Epoch 00007: val_loss improved from 0.00060 to 0.00048, saving model to model_checkpoint/2021-12-10_UAL.h5
# 50/50 [==============================] - 27s 546ms/step - loss: 9.0251e-04 - mean_absolute_error: 0.0305 - val_loss: 4.7869e-04 - val_mean_absolute_error: 0.0226
# Epoch 8/10
# 50/50 [==============================] - ETA: 0s - loss: 8.0492e-04 - mean_absolute_error: 0.0287
# Epoch 00008: val_loss did not improve from 0.00048
# 50/50 [==============================] - 26s 514ms/step - loss: 8.0492e-04 - mean_absolute_error: 0.0287 - val_loss: 6.3884e-04 - val_mean_absolute_error: 0.0264
# Epoch 9/10
# 50/50 [==============================] - ETA: 0s - loss: 8.9325e-04 - mean_absolute_error: 0.0302
# Epoch 00009: val_loss did not improve from 0.00048
# 50/50 [==============================] - 27s 549ms/step - loss: 8.9325e-04 - mean_absolute_error: 0.0302 - val_loss: 5.0639e-04 - val_mean_absolute_error: 0.0237
# Epoch 10/10
# 50/50 [==============================] - ETA: 0s - loss: 8.3175e-04 - mean_absolute_error: 0.0294
# Epoch 00010: val_loss did not improve from 0.00048
# 50/50 [==============================] - 26s 527ms/step - loss: 8.3175e-04 - mean_absolute_error: 0.0294 - val_loss: 5.7716e-04 - val_mean_absolute_error: 0.0245

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 25/25 [==============================] - 2s 85ms/step - loss: 4.7869e-04 - mean_absolute_error: 0.0226
# (1, 50, 5)
# Future price after 1 days is 41.91$
# Loss: 0.0004786899662576616
# Mean absolute error: 5.241995465741347

# %%
ticker = 'SNOW'
window = 50
predict = 1
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0594 - mean_absolute_error: 0.2495
# Epoch 00001: val_loss improved from inf to 0.01403, saving model to model_checkpoint/2021-12-10_SNOW.h5
# 4/4 [==============================] - 10s 1s/step - loss: 0.0594 - mean_absolute_error: 0.2495 - val_loss: 0.0140 - val_mean_absolute_error: 0.1188
# Epoch 2/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0176 - mean_absolute_error: 0.1456
# Epoch 00002: val_loss did not improve from 0.01403
# 4/4 [==============================] - 3s 655ms/step - loss: 0.0176 - mean_absolute_error: 0.1456 - val_loss: 0.0310 - val_mean_absolute_error: 0.1965
# Epoch 3/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0175 - mean_absolute_error: 0.1449
# Epoch 00003: val_loss did not improve from 0.01403
# 4/4 [==============================] - 3s 579ms/step - loss: 0.0175 - mean_absolute_error: 0.1449 - val_loss: 0.0199 - val_mean_absolute_error: 0.1665
# Epoch 4/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0122 - mean_absolute_error: 0.1233
# Epoch 00004: val_loss did not improve from 0.01403
# 4/4 [==============================] - 2s 484ms/step - loss: 0.0122 - mean_absolute_error: 0.1233 - val_loss: 0.0151 - val_mean_absolute_error: 0.1215
# Epoch 5/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0112 - mean_absolute_error: 0.1133
# Epoch 00005: val_loss improved from 0.01403 to 0.01152, saving model to model_checkpoint/2021-12-10_SNOW.h5
# 4/4 [==============================] - 2s 490ms/step - loss: 0.0112 - mean_absolute_error: 0.1133 - val_loss: 0.0115 - val_mean_absolute_error: 0.1123
# Epoch 6/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0096 - mean_absolute_error: 0.1090
# Epoch 00006: val_loss improved from 0.01152 to 0.00998, saving model to model_checkpoint/2021-12-10_SNOW.h5
# 4/4 [==============================] - 2s 482ms/step - loss: 0.0096 - mean_absolute_error: 0.1090 - val_loss: 0.0100 - val_mean_absolute_error: 0.0990
# Epoch 7/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0068 - mean_absolute_error: 0.0869
# Epoch 00007: val_loss improved from 0.00998 to 0.00978, saving model to model_checkpoint/2021-12-10_SNOW.h5
# 4/4 [==============================] - 2s 506ms/step - loss: 0.0068 - mean_absolute_error: 0.0869 - val_loss: 0.0098 - val_mean_absolute_error: 0.0954
# Epoch 8/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0065 - mean_absolute_error: 0.0871
# Epoch 00008: val_loss improved from 0.00978 to 0.00954, saving model to model_checkpoint/2021-12-10_SNOW.h5
# 4/4 [==============================] - 2s 501ms/step - loss: 0.0065 - mean_absolute_error: 0.0871 - val_loss: 0.0095 - val_mean_absolute_error: 0.0973
# Epoch 9/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0062 - mean_absolute_error: 0.0837
# Epoch 00009: val_loss improved from 0.00954 to 0.00861, saving model to model_checkpoint/2021-12-10_SNOW.h5
# 4/4 [==============================] - 2s 449ms/step - loss: 0.0062 - mean_absolute_error: 0.0837 - val_loss: 0.0086 - val_mean_absolute_error: 0.0901
# Epoch 10/10
# 4/4 [==============================] - ETA: 0s - loss: 0.0065 - mean_absolute_error: 0.0852
# Epoch 00010: val_loss did not improve from 0.00861
# 4/4 [==============================] - 2s 430ms/step - loss: 0.0065 - mean_absolute_error: 0.0852 - val_loss: 0.0093 - val_mean_absolute_error: 0.0976

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0086 - mean_absolute_error: 0.0901
# (1, 50, 5)
# Future price after 1 days is 341.90$
# Loss: 0.008613144047558308
# Mean absolute error: 207.49137671048595

# %%
ticker = 'NFLX'
window = 50
predict = 1
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 61/61 [==============================] - ETA: 0s - loss: 0.0082 - mean_absolute_error: 0.0522
# Epoch 00001: val_loss improved from inf to 0.00022, saving model to model_checkpoint/2021-12-10_NFLX.h5
# 61/61 [==============================] - 42s 579ms/step - loss: 0.0082 - mean_absolute_error: 0.0522 - val_loss: 2.1864e-04 - val_mean_absolute_error: 0.0123
# Epoch 2/10
# 61/61 [==============================] - ETA: 0s - loss: 3.4237e-04 - mean_absolute_error: 0.0134
# Epoch 00002: val_loss did not improve from 0.00022
# 61/61 [==============================] - 45s 744ms/step - loss: 3.4237e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9347e-04 - val_mean_absolute_error: 0.0125
# Epoch 3/10
# 61/61 [==============================] - ETA: 0s - loss: 4.7969e-04 - mean_absolute_error: 0.0153
# Epoch 00003: val_loss improved from 0.00022 to 0.00017, saving model to model_checkpoint/2021-12-10_NFLX.h5
# 61/61 [==============================] - 35s 582ms/step - loss: 4.7969e-04 - mean_absolute_error: 0.0153 - val_loss: 1.7058e-04 - val_mean_absolute_error: 0.0106
# Epoch 4/10
# 61/61 [==============================] - ETA: 0s - loss: 2.9275e-04 - mean_absolute_error: 0.0123
# Epoch 00004: val_loss improved from 0.00017 to 0.00016, saving model to model_checkpoint/2021-12-10_NFLX.h5
# 61/61 [==============================] - 34s 558ms/step - loss: 2.9275e-04 - mean_absolute_error: 0.0123 - val_loss: 1.5628e-04 - val_mean_absolute_error: 0.0088
# Epoch 5/10
# 61/61 [==============================] - ETA: 0s - loss: 3.0001e-04 - mean_absolute_error: 0.0123
# Epoch 00005: val_loss did not improve from 0.00016
# 61/61 [==============================] - 32s 529ms/step - loss: 3.0001e-04 - mean_absolute_error: 0.0123 - val_loss: 2.1582e-04 - val_mean_absolute_error: 0.0099
# Epoch 6/10
# 61/61 [==============================] - ETA: 0s - loss: 3.1869e-04 - mean_absolute_error: 0.0126
# Epoch 00006: val_loss did not improve from 0.00016
# 61/61 [==============================] - 37s 605ms/step - loss: 3.1869e-04 - mean_absolute_error: 0.0126 - val_loss: 2.3155e-04 - val_mean_absolute_error: 0.0121
# Epoch 7/10
# 61/61 [==============================] - ETA: 0s - loss: 3.5626e-04 - mean_absolute_error: 0.0135
# Epoch 00007: val_loss did not improve from 0.00016
# 61/61 [==============================] - 37s 596ms/step - loss: 3.5626e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5859e-04 - val_mean_absolute_error: 0.0088
# Epoch 8/10
# 61/61 [==============================] - ETA: 0s - loss: 3.2020e-04 - mean_absolute_error: 0.0128
# Epoch 00008: val_loss improved from 0.00016 to 0.00015, saving model to model_checkpoint/2021-12-10_NFLX.h5
# 61/61 [==============================] - 33s 539ms/step - loss: 3.2020e-04 - mean_absolute_error: 0.0128 - val_loss: 1.4699e-04 - val_mean_absolute_error: 0.0096
# Epoch 9/10
# 61/61 [==============================] - ETA: 0s - loss: 2.9765e-04 - mean_absolute_error: 0.0120
# Epoch 00009: val_loss did not improve from 0.00015
# 61/61 [==============================] - 40s 652ms/step - loss: 2.9765e-04 - mean_absolute_error: 0.0120 - val_loss: 2.6532e-04 - val_mean_absolute_error: 0.0114
# Epoch 10/10
# 61/61 [==============================] - ETA: 0s - loss: 3.0379e-04 - mean_absolute_error: 0.0125
# Epoch 00010: val_loss did not improve from 0.00015
# 61/61 [==============================] - 36s 600ms/step - loss: 3.0379e-04 - mean_absolute_error: 0.0125 - val_loss: 1.8315e-04 - val_mean_absolute_error: 0.0097

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 31/31 [==============================] - 3s 82ms/step - loss: 1.4699e-04 - mean_absolute_error: 0.0096
# (1, 50, 5)
# Future price after 1 days is 640.13$
# Loss: 0.0001469863491365686
# Mean absolute error: 7.029644427189856

# %%
ticker = 'MDT'
window = 50
predict = 1
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 153/153 [==============================] - ETA: 0s - loss: 0.0012 - mean_absolute_error: 0.0243
# Epoch 00001: val_loss improved from inf to 0.00010, saving model to model_checkpoint/2021-12-10_MDT.h5
# 153/153 [==============================] - 101s 606ms/step - loss: 0.0012 - mean_absolute_error: 0.0243 - val_loss: 9.8427e-05 - val_mean_absolute_error: 0.0086
# Epoch 2/10
# 153/153 [==============================] - ETA: 0s - loss: 2.2631e-04 - mean_absolute_error: 0.0124
# Epoch 00002: val_loss improved from 0.00010 to 0.00005, saving model to model_checkpoint/2021-12-10_MDT.h5
# 153/153 [==============================] - 79s 517ms/step - loss: 2.2631e-04 - mean_absolute_error: 0.0124 - val_loss: 4.8953e-05 - val_mean_absolute_error: 0.0054
# Epoch 3/10
# 153/153 [==============================] - ETA: 0s - loss: 2.4750e-04 - mean_absolute_error: 0.0127
# Epoch 00003: val_loss did not improve from 0.00005
# 153/153 [==============================] - 80s 523ms/step - loss: 2.4750e-04 - mean_absolute_error: 0.0127 - val_loss: 1.9054e-04 - val_mean_absolute_error: 0.0118
# Epoch 4/10
# 153/153 [==============================] - ETA: 0s - loss: 2.7003e-04 - mean_absolute_error: 0.0141
# Epoch 00004: val_loss did not improve from 0.00005
# 153/153 [==============================] - 78s 510ms/step - loss: 2.7003e-04 - mean_absolute_error: 0.0141 - val_loss: 7.6243e-05 - val_mean_absolute_error: 0.0099
# Epoch 5/10
# 153/153 [==============================] - ETA: 0s - loss: 2.3024e-04 - mean_absolute_error: 0.0129
# Epoch 00005: val_loss did not improve from 0.00005
# 153/153 [==============================] - 85s 555ms/step - loss: 2.3024e-04 - mean_absolute_error: 0.0129 - val_loss: 5.0198e-05 - val_mean_absolute_error: 0.0060
# Epoch 6/10
# 153/153 [==============================] - ETA: 0s - loss: 1.8180e-04 - mean_absolute_error: 0.0115
# Epoch 00006: val_loss did not improve from 0.00005
# 153/153 [==============================] - 80s 523ms/step - loss: 1.8180e-04 - mean_absolute_error: 0.0115 - val_loss: 7.0795e-05 - val_mean_absolute_error: 0.0083
# Epoch 7/10
# 153/153 [==============================] - ETA: 0s - loss: 1.7924e-04 - mean_absolute_error: 0.0117
# Epoch 00007: val_loss did not improve from 0.00005
# 153/153 [==============================] - 80s 520ms/step - loss: 1.7924e-04 - mean_absolute_error: 0.0117 - val_loss: 1.0083e-04 - val_mean_absolute_error: 0.0090
# Epoch 8/10
# 153/153 [==============================] - ETA: 0s - loss: 1.7507e-04 - mean_absolute_error: 0.0117
# Epoch 00008: val_loss did not improve from 0.00005
# 153/153 [==============================] - 80s 522ms/step - loss: 1.7507e-04 - mean_absolute_error: 0.0117 - val_loss: 6.9949e-05 - val_mean_absolute_error: 0.0069
# Epoch 9/10
# 153/153 [==============================] - ETA: 0s - loss: 1.5194e-04 - mean_absolute_error: 0.0109
# Epoch 00009: val_loss did not improve from 0.00005
# 153/153 [==============================] - 83s 540ms/step - loss: 1.5194e-04 - mean_absolute_error: 0.0109 - val_loss: 1.2243e-04 - val_mean_absolute_error: 0.0096
# Epoch 10/10
# 153/153 [==============================] - ETA: 0s - loss: 1.7949e-04 - mean_absolute_error: 0.0120
# Epoch 00010: val_loss did not improve from 0.00005
# 153/153 [==============================] - 86s 561ms/step - loss: 1.7949e-04 - mean_absolute_error: 0.0120 - val_loss: 1.3279e-04 - val_mean_absolute_error: 0.0106

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 77/77 [==============================] - 6s 79ms/step - loss: 4.8953e-05 - mean_absolute_error: 0.0054
# (1, 50, 5)
# Future price after 1 days is 112.23$
# Loss: 4.895283200312406e-05
# Mean absolute error: 0.8149630077212631

# %%
ticker = 'BA'
window = 50
predict = 1
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 154/154 [==============================] - ETA: 0s - loss: 8.1956e-04 - mean_absolute_error: 0.0183
# Epoch 00001: val_loss improved from inf to 0.00015, saving model to model_checkpoint/2021-12-10_BA.h5
# 154/154 [==============================] - 108s 635ms/step - loss: 8.1956e-04 - mean_absolute_error: 0.0183 - val_loss: 1.5039e-04 - val_mean_absolute_error: 0.0076
# Epoch 2/10
# 154/154 [==============================] - ETA: 0s - loss: 3.2798e-04 - mean_absolute_error: 0.0128
# Epoch 00002: val_loss improved from 0.00015 to 0.00014, saving model to model_checkpoint/2021-12-10_BA.h5
# 154/154 [==============================] - 84s 542ms/step - loss: 3.2798e-04 - mean_absolute_error: 0.0128 - val_loss: 1.4350e-04 - val_mean_absolute_error: 0.0112
# Epoch 3/10
# 154/154 [==============================] - ETA: 0s - loss: 4.4106e-04 - mean_absolute_error: 0.0146
# Epoch 00003: val_loss did not improve from 0.00014
# 154/154 [==============================] - 79s 510ms/step - loss: 4.4106e-04 - mean_absolute_error: 0.0146 - val_loss: 2.7250e-04 - val_mean_absolute_error: 0.0139
# Epoch 4/10
# 154/154 [==============================] - ETA: 0s - loss: 2.6841e-04 - mean_absolute_error: 0.0114
# Epoch 00004: val_loss did not improve from 0.00014
# 154/154 [==============================] - 79s 517ms/step - loss: 2.6841e-04 - mean_absolute_error: 0.0114 - val_loss: 7.8914e-04 - val_mean_absolute_error: 0.0287
# Epoch 5/10
# 154/154 [==============================] - ETA: 0s - loss: 2.1453e-04 - mean_absolute_error: 0.0103
# Epoch 00005: val_loss did not improve from 0.00014
# 154/154 [==============================] - 85s 553ms/step - loss: 2.1453e-04 - mean_absolute_error: 0.0103 - val_loss: 1.8084e-04 - val_mean_absolute_error: 0.0113
# Epoch 6/10
# 154/154 [==============================] - ETA: 0s - loss: 1.7971e-04 - mean_absolute_error: 0.0097
# Epoch 00006: val_loss improved from 0.00014 to 0.00008, saving model to model_checkpoint/2021-12-10_BA.h5
# 154/154 [==============================] - 88s 572ms/step - loss: 1.7971e-04 - mean_absolute_error: 0.0097 - val_loss: 8.2121e-05 - val_mean_absolute_error: 0.0056
# Epoch 7/10
# 154/154 [==============================] - ETA: 0s - loss: 1.6014e-04 - mean_absolute_error: 0.0092
# Epoch 00007: val_loss did not improve from 0.00008
# 154/154 [==============================] - 83s 536ms/step - loss: 1.6014e-04 - mean_absolute_error: 0.0092 - val_loss: 2.1137e-04 - val_mean_absolute_error: 0.0114
# Epoch 8/10
# 154/154 [==============================] - ETA: 0s - loss: 1.5381e-04 - mean_absolute_error: 0.0092
# Epoch 00008: val_loss did not improve from 0.00008
# 154/154 [==============================] - 80s 521ms/step - loss: 1.5381e-04 - mean_absolute_error: 0.0092 - val_loss: 8.8988e-05 - val_mean_absolute_error: 0.0053
# Epoch 9/10
# 154/154 [==============================] - ETA: 0s - loss: 1.9072e-04 - mean_absolute_error: 0.0100
# Epoch 00009: val_loss improved from 0.00008 to 0.00004, saving model to model_checkpoint/2021-12-10_BA.h5
# 154/154 [==============================] - 89s 579ms/step - loss: 1.9072e-04 - mean_absolute_error: 0.0100 - val_loss: 4.2790e-05 - val_mean_absolute_error: 0.0053
# Epoch 10/10
# 154/154 [==============================] - ETA: 0s - loss: 1.8919e-04 - mean_absolute_error: 0.0106
# Epoch 00010: val_loss did not improve from 0.00004
# 154/154 [==============================] - 83s 540ms/step - loss: 1.8919e-04 - mean_absolute_error: 0.0106 - val_loss: 5.0623e-05 - val_mean_absolute_error: 0.0043

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 77/77 [==============================] - 6s 71ms/step - loss: 4.2790e-05 - mean_absolute_error: 0.0053
# (1, 50, 5)
# Future price after 1 days is 202.06$
# Loss: 4.27896884502843e-05
# Mean absolute error: 2.4854778386829137

# %%
ticker = 'DHR'
window = 50
predict = 1
layers = 4
units = 256
dropout = 0.2
date = time.strftime("%Y-%m-%d")
eps = 10
b_size=64

ticker_filename = os.path.join('data', f'{date}_{ticker}.csv')
model_name = f'{date}_{ticker}'

data = get_data(ticker, window, predict)
data['original df'].to_csv(ticker_filename)

model = make_LSTM_model(window, len(features), layers, units, dropout)
m_checkpoint = ModelCheckpoint(filepath=os.path.join('model_checkpoint', model_name + '.h5'), 
                                save_best_only=True, save_weights_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join('tensorboard', model_name))

model_history = model.fit(data['x train'], data['y train'], batch_size=b_size, epochs=eps, validation_data=(data['x test'], data['y test']), 
                            callbacks=[m_checkpoint, tensorboard], verbose=1)
# Out:
# Epoch 1/10
# 135/135 [==============================] - ETA: 0s - loss: 4.6905e-04 - mean_absolute_error: 0.0122
# Epoch 00001: val_loss improved from inf to 0.00047, saving model to model_checkpoint/2021-12-10_DHR.h5
# 135/135 [==============================] - 92s 630ms/step - loss: 4.6905e-04 - mean_absolute_error: 0.0122 - val_loss: 4.7194e-04 - val_mean_absolute_error: 0.0175
# Epoch 2/10
# 135/135 [==============================] - ETA: 0s - loss: 2.4362e-04 - mean_absolute_error: 0.0107
# Epoch 00002: val_loss improved from 0.00047 to 0.00003, saving model to model_checkpoint/2021-12-10_DHR.h5
# 135/135 [==============================] - 79s 583ms/step - loss: 2.4362e-04 - mean_absolute_error: 0.0107 - val_loss: 2.5851e-05 - val_mean_absolute_error: 0.0033
# Epoch 3/10
# 135/135 [==============================] - ETA: 0s - loss: 1.1314e-04 - mean_absolute_error: 0.0076
# Epoch 00003: val_loss did not improve from 0.00003
# 135/135 [==============================] - 78s 581ms/step - loss: 1.1314e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9411e-05 - val_mean_absolute_error: 0.0038
# Epoch 4/10
# 135/135 [==============================] - ETA: 0s - loss: 1.2599e-04 - mean_absolute_error: 0.0084
# Epoch 00004: val_loss did not improve from 0.00003
# 135/135 [==============================] - 77s 569ms/step - loss: 1.2599e-04 - mean_absolute_error: 0.0084 - val_loss: 4.4573e-05 - val_mean_absolute_error: 0.0058
# Epoch 5/10
# 135/135 [==============================] - ETA: 0s - loss: 1.2595e-04 - mean_absolute_error: 0.0079
# Epoch 00005: val_loss improved from 0.00003 to 0.00002, saving model to model_checkpoint/2021-12-10_DHR.h5
# 135/135 [==============================] - 77s 568ms/step - loss: 1.2595e-04 - mean_absolute_error: 0.0079 - val_loss: 2.2679e-05 - val_mean_absolute_error: 0.0030
# Epoch 6/10
# 135/135 [==============================] - ETA: 0s - loss: 1.1495e-04 - mean_absolute_error: 0.0078
# Epoch 00006: val_loss did not improve from 0.00002
# 135/135 [==============================] - 75s 553ms/step - loss: 1.1495e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2939e-04 - val_mean_absolute_error: 0.0092
# Epoch 7/10
# 135/135 [==============================] - ETA: 0s - loss: 1.2269e-04 - mean_absolute_error: 0.0079
# Epoch 00007: val_loss did not improve from 0.00002
# 135/135 [==============================] - 71s 523ms/step - loss: 1.2269e-04 - mean_absolute_error: 0.0079 - val_loss: 3.9753e-05 - val_mean_absolute_error: 0.0039
# Epoch 8/10
# 135/135 [==============================] - ETA: 0s - loss: 1.5977e-04 - mean_absolute_error: 0.0093
# Epoch 00008: val_loss did not improve from 0.00002
# 135/135 [==============================] - 70s 517ms/step - loss: 1.5977e-04 - mean_absolute_error: 0.0093 - val_loss: 2.7111e-05 - val_mean_absolute_error: 0.0050
# Epoch 9/10
# 135/135 [==============================] - ETA: 0s - loss: 1.0070e-04 - mean_absolute_error: 0.0077
# Epoch 00009: val_loss did not improve from 0.00002
# 135/135 [==============================] - 68s 503ms/step - loss: 1.0070e-04 - mean_absolute_error: 0.0077 - val_loss: 1.5338e-04 - val_mean_absolute_error: 0.0095
# Epoch 10/10
# 135/135 [==============================] - ETA: 0s - loss: 1.4923e-04 - mean_absolute_error: 0.0097
# Epoch 00010: val_loss did not improve from 0.00002
# 135/135 [==============================] - 70s 517ms/step - loss: 1.4923e-04 - mean_absolute_error: 0.0097 - val_loss: 4.5863e-05 - val_mean_absolute_error: 0.0078

# %%
model_path = os.path.join('model_checkpoint', model_name) + '.h5' 
model.load_weights(model_path)
loss, mae = model.evaluate(data['x test'], data['y test'], verbose=1)
mean_abs_error = data['scalers']['adjclose'].inverse_transform([[mae]])[0][0]
finished_df = get_finished_df(model, data)
future_price = make_prediction(model, data)
print(f'Future price after {predict} days is {future_price:.2f}$')
print(f'Loss: {loss}')
print(f'Mean absolute error: {mean_abs_error}')
plot(finished_df)

csv_result_folder = 'csv_results'
if not os.path.isdir(csv_result_folder):
    os.mkdir(csv_result_folder)
csv_filename = os.path.join(csv_result_folder, model_name + '.csv')
finished_df.to_csv(csv_filename)
# Out:
# 68/68 [==============================] - 5s 71ms/step - loss: 2.2679e-05 - mean_absolute_error: 0.0030
# (1, 50, 5)
# Future price after 1 days is 324.33$
# Loss: 2.2679056201013736e-05
# Mean absolute error: 1.0414957749664056
