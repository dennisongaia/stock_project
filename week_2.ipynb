# %% [markdown]
# # Week 2

# %% [markdown]
# Because of my lack of expertise when it comes to the stock market, I thought using machine learning might be a better approach, rather than manually trying to interpret complex technical indicators like I did last week. This week I began refreshing my Tensorflow knowledge, and based on many articles that I read this week (such as this: https://cs230.stanford.edu/projects_fall_2019/reports/26254244.pdf) I decided to work on creating a Long Short-Term Memory (LSTM) Recurrent neural network, as it is used for time series forecasting. I began by getting data using yahoo_fin and working on preprocessing it. By next week I hope to have built and trained my model so that I can start implementing my new technique. For my trades this week I reutilized my technical indicator approach from last week.

# %%
pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.8.9.1)
# Requirement already satisfied: requests-html in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (1.3.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (2.26.0)
# Requirement already satisfied: feedparser in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (6.0.8)
# Requirement already satisfied: sgmllib3k in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->yahoo_fin) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->yahoo_fin) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.2.6)
# Requirement already satisfied: parse in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: bs4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: w3lib in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: pyquery in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: fake-useragent in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.62.3)
# Requirement already satisfied: websockets<10.0,>=9.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (9.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from bs4->requests-html->yahoo_fin) (4.10.0)
# Requirement already satisfied: lxml>=2.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (4.6.4)
# Requirement already satisfied: cssselect>0.7.9 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (1.3.4)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from yahoo_fin import stock_info as si

# %%
si.tickers_nasdaq()
# Out:
# ['AACG',
#  'AACI',
#  'AACIU',
#  'AACIW',
#  'AADI',
#  'AADR',
#  'AAL',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPL',
#  'AATC',
#  'AAWW',
#  'AAXJ',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEO',
#  'ABGI',
#  'ABIO',
#  'ABMD',
#  'ABNB',
#  'ABOS',
#  'ABSI',
#  'ABST',
#  'ABTX',
#  'ABUS',
#  'ABVC',
#  'ACAD',
#  'ACAH',
#  'ACAHU',
#  'ACAHW',
#  'ACB',
#  'ACBA',
#  'ACBAU',
#  'ACBAW',
#  'ACBI',
#  'ACCD',
#  'ACER',
#  'ACET',
#  'ACEV',
#  'ACEVU',
#  'ACEVW',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACHC',
#  'ACHL',
#  'ACHV',
#  'ACIU',
#  'ACIW',
#  'ACKIT',
#  'ACKIU',
#  'ACKIW',
#  'ACLS',
#  'ACMR',
#  'ACNB',
#  'ACOR',
#  'ACQR',
#  'ACQRU',
#  'ACQRW',
#  'ACRS',
#  'ACRX',
#  'ACST',
#  'ACT',
#  'ACTD',
#  'ACTDU',
#  'ACTDW',
#  'ACTG',
#  'ACVA',
#  'ACWI',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADALU',
#  'ADAP',
#  'ADBE',
#  'ADER',
#  'ADERU',
#  'ADERW',
#  'ADES',
#  'ADGI',
#  'ADI',
#  'ADIL',
#  'ADILW',
#  'ADMA',
#  'ADMP',
#  'ADN',
#  'ADNWW',
#  'ADOC',
#  'ADOCR',
#  'ADOCW',
#  'ADP',
#  'ADPT',
#  'ADRE',
#  'ADSK',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADVWW',
#  'ADXN',
#  'ADXS',
#  'AEAC',
#  'AEACU',
#  'AEACW',
#  'AEAEU',
#  'AEHA',
#  'AEHAU',
#  'AEHAW',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEMD',
#  'AEP',
#  'AEPPL',
#  'AEPPZ',
#  'AERC',
#  'AERI',
#  'AESE',
#  'AEY',
#  'AEYE',
#  'AEZS',
#  'AFACU',
#  'AFAQ',
#  'AFAQU',
#  'AFAQW',
#  'AFBI',
#  'AFCG',
#  'AFIB',
#  'AFIN',
#  'AFINO',
#  'AFINP',
#  'AFMD',
#  'AFRM',
#  'AFYA',
#  'AGBA',
#  'AGBAR',
#  'AGBAU',
#  'AGBAW',
#  'AGC',
#  'AGCUU',
#  'AGCWW',
#  'AGEN',
#  'AGFS',
#  'AGFY',
#  'AGGR',
#  'AGGRU',
#  'AGGRW',
#  'AGIL',
#  'AGILW',
#  'AGIO',
#  'AGLE',
#  'AGMH',
#  'AGNC',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGNG',
#  'AGRI',
#  'AGRIW',
#  'AGRX',
#  'AGTC',
#  'AGYS',
#  'AGZD',
#  'AHCO',
#  'AHI',
#  'AHPA',
#  'AHPAU',
#  'AHPAW',
#  'AHPI',
#  'AIA',
#  'AIH',
#  'AIHS',
#  'AIKI',
#  'AIMC',
#  'AINV',
#  'AIP',
#  'AIQ',
#  'AIRG',
#  'AIRR',
#  'AIRS',
#  'AIRT',
#  'AIRTP',
#  'AKAM',
#  'AKBA',
#  'AKIC',
#  'AKICU',
#  'AKICW',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKU',
#  'AKUS',
#  'AKYA',
#  'ALAC',
#  'ALACR',
#  'ALACU',
#  'ALACW',
#  'ALBO',
#  'ALCO',
#  'ALDX',
#  'ALEC',
#  'ALF',
#  'ALFIW',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIM',
#  'ALJJ',
#  'ALKS',
#  'ALKT',
#  'ALLK',
#  'ALLO',
#  'ALLT',
#  'ALNA',
#  'ALNY',
#  'ALORU',
#  'ALOT',
#  'ALPA',
#  'ALPAU',
#  'ALPAW',
#  'ALPN',
#  'ALPP',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALT',
#  'ALTM',
#  'ALTO',
#  'ALTR',
#  'ALTU',
#  'ALTUU',
#  'ALTUW',
#  'ALTY',
#  'ALVR',
#  'ALXO',
#  'ALYA',
#  'ALZN',
#  'AMAL',
#  'AMAO',
#  'AMAOU',
#  'AMAOW',
#  'AMAT',
#  'AMBA',
#  'AMCI',
#  'AMCIU',
#  'AMCIW',
#  'AMCX',
#  'AMD',
#  'AMED',
#  'AMEH',
#  'AMGN',
#  'AMKR',
#  'AMNB',
#  'AMOT',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPL',
#  'AMRK',
#  'AMRN',
#  'AMRS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMSWA',
#  'AMTB',
#  'AMTI',
#  'AMTX',
#  'AMWD',
#  'AMYT',
#  'AMZN',
#  'ANAB',
#  'ANAT',
#  'ANDE',
#  'ANEB',
#  'ANGI',
#  'ANGL',
#  'ANGN',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANPC',
#  'ANSS',
#  'ANTE',
#  'ANY',
#  'ANZU',
#  'ANZUU',
#  'ANZUW',
#  'AOSL',
#  'AOUT',
#  'APA',
#  'APAC',
#  'APACU',
#  'APACW',
#  'APDN',
#  'APEI',
#  'APEN',
#  'API',
#  'APLS',
#  'APLT',
#  'APM',
#  'APMI',
#  'APMIU',
#  'APMIW',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPH',
#  'APPHW',
#  'APPN',
#  'APPS',
#  'APR',
#  'APRE',
#  'APTM',
#  'APTMU',
#  'APTMW',
#  'APTO',
#  'APTX',
#  'APVO',
#  'APWC',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQST',
#  'AQWA',
#  'ARAV',
#  'ARAY',
#  'ARBE',
#  'ARBEW',
#  'ARBG',
#  'ARBGU',
#  'ARBGW',
#  'ARBK',
#  'ARBKL',
#  'ARCB',
#  'ARCC',
#  'ARCE',
#  'ARCKU',
#  'ARCT',
#  'ARDS',
#  'ARDX',
#  'AREC',
#  'ARGU',
#  'ARGUU',
#  'ARGUW',
#  'ARGX',
#  'ARHS',
#  'ARIZU',
#  'ARKO',
#  'ARKOW',
#  'ARKR',
#  'ARLP',
#  'ARNA',
#  'AROW',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARRW',
#  'ARRWU',
#  'ARRWW',
#  'ARRY',
#  'ARTA',
#  'ARTAU',
#  'ARTAW',
#  'ARTE',
#  'ARTEU',
#  'ARTEW',
#  'ARTL',
#  'ARTLW',
#  'ARTNA',
#  'ARTW',
#  'ARVL',
#  'ARVN',
#  'ARWR',
#  'ARYD',
#  'ARYE',
#  'ASAX',
#  'ASAXU',
#  'ASAXW',
#  'ASET',
#  'ASLE',
#  'ASLEW',
#  'ASLN',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASO',
#  'ASPA',
#  'ASPAU',
#  'ASPAW',
#  'ASPC',
#  'ASPCU',
#  'ASPCW',
#  'ASPS',
#  'ASPU',
#  'ASRT',
#  'ASRV',
#  'ASTC',
#  'ASTE',
#  'ASTL',
#  'ASTLW',
#  'ASTR',
#  'ASTRW',
#  'ASTS',
#  'ASTSW',
#  'ASUR',
#  'ASYS',
#  'ATAI',
#  'ATAX',
#  'ATCOL',
#  'ATCX',
#  'ATEC',
#  'ATER',
#  'ATEX',
#  'ATHA',
#  'ATHE',
#  'ATHX',
#  'ATIF',
#  'ATLC',
#  'ATLCL',
#  'ATLCP',
#  'ATLO',
#  'ATNF',
#  'ATNFW',
#  'ATNI',
#  'ATNX',
#  'ATOM',
#  'ATOS',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATRS',
#  'ATSG',
#  'ATSPT',
#  'ATSPU',
#  'ATSPW',
#  'ATVC',
#  'ATVCU',
#  'ATVCW',
#  'ATVI',
#  'ATXI',
#  'ATXS',
#  'ATY',
#  'AUB',
#  'AUBAP',
#  'AUBN',
#  'AUDC',
#  'AUGX',
#  'AUID',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AURC',
#  'AURCU',
#  'AURCW',
#  'AUROW',
#  'AUTL',
#  'AUTO',
#  'AUUD',
#  'AUUDW',
#  'AUVI',
#  'AUVIP',
#  'AVACU',
#  'AVAH',
#  'AVAV',
#  'AVCO',
#  'AVCT',
#  'AVCTW',
#  'AVDL',
#  'AVDX',
#  'AVEO',
#  'AVGO',
#  'AVGOP',
#  'AVGR',
#  'AVHI',
#  'AVHIU',
#  'AVHIW',
#  'AVID',
#  'AVIR',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVPTW',
#  'AVRO',
#  'AVT',
#  'AVTE',
#  'AVTX',
#  'AVXL',
#  'AWH',
#  'AWRE',
#  'AXDX',
#  'AXGN',
#  'AXLA',
#  'AXNX',
#  'AXON',
#  'AXSM',
#  'AXTI',
#  'AY',
#  'AYLA',
#  'AYRO',
#  'AYTU',
#  'AZN',
#  'AZPN',
#  'AZYO',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BASE',
#  'BATRA',
#  'BATRK',
#  'BBBY',
#  'BBCP',
#  'BBGI',
#  'BBH',
#  'BBI',
#  'BBIG',
#  'BBIO',
#  'BBLG',
#  'BBLGW',
#  'BBQ',
#  'BBSI',
#  'BCAB',
#  'BCAC',
#  'BCACU',
#  'BCACW',
#  'BCBP',
#  'BCDA',
#  'BCDAW',
#  'BCEL',
#  'BCLI',
#  'BCML',
#  'BCOR',
#  'BCOV',
#  'BCOW',
#  'BCPC',
#  'BCRX',
#  'BCSAU',
#  'BCTX',
#  'BCTXW',
#  'BCYC',
#  'BDSI',
#  'BDSX',
#  'BDTX',
#  'BEAM',
#  'BEAT',
#  'BEATW',
#  'BECN',
#  'BEEM',
#  'BEEMW',
#  'BELFA',
#  'BELFB',
#  'BENE',
#  'BENER',
#  'BENEU',
#  'BENEW',
#  'BFC',
#  'BFI',
#  'BFIIW',
#  'BFIN',
#  'BFIT',
#  'BFRA',
#  'BFRI',
#  'BFRIW',
#  'BFST',
#  'BGCP',
#  'BGFV',
#  'BGNE',
#  'BGRN',
#  'BGRY',
#  'BGRYW',
#  'BHAC',
#  'BHACU',
#  'BHACW',
#  'BHAT',
#  'BHF',
#  'BHFAL',
#  'BHFAM',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BHSE',
#  'BHSEU',
#  'BHSEW',
#  'BHTG',
#  'BIB',
#  'BICK',
#  'BIDU',
#  'BIGC',
#  'BIIB',
#  'BILI',
#  'BIMI',
#  'BIOC',
#  'BIOL',
#  'BIOT',
#  'BIOTU',
#  'BIOTW',
#  'BIOX',
#  'BIRD',
#  'BIS',
#  'BITF',
#  'BITS',
#  'BIVI',
#  'BJDX',
#  'BJK',
#  'BJRI',
#  'BKCC',
#  'BKCH',
#  'BKEP',
#  'BKEPP',
#  'BKNG',
#  'BKSC',
#  'BKYI',
#  'BL',
#  'BLBD',
#  'BLBX',
#  'BLCM',
#  'BLCN',
#  'BLCT',
#  'BLDE',
#  'BLDEW',
#  'BLDP',
#  'BLEUU',
#  'BLFS',
#  'BLFY',
#  'BLI',
#  'BLIN',
#  'BLKB',
#  'BLMN',
#  'BLNG',
#  'BLNGU',
#  'BLNGW',
#  'BLNK',
#  'BLNKW',
#  'BLPH',
#  'BLRX',
#  'BLSA',
#  'BLTS',
#  'BLTSU',
#  'BLTSW',
#  'BLU',
#  'BLUE',
#  'BLZE',
#  'BMAQ',
#  'BMAQR',
#  'BMAQU',
#  'BMAQW',
#  'BMBL',
#  'BMEA',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BMTC',
#  'BND',
#  'BNDW',
#  'BNDX',
#  'BNFT',
#  'BNGO',
#  'BNGOW',
#  'BNIX',
#  'BNIXR',
#  'BNIXW',
#  'BNNR',
#  'BNNRU',
#  'BNNRW',
#  'BNR',
#  'BNSO',
#  'BNTC',
#  'BNTX',
#  'BOKF',
#  'BOLT',
#  'BOMN',
#  'BON',
#  'BOOM',
#  'BOSC',
#  'BOTJ',
#  'BOTZ',
#  'BOXL',
#  'BPMC',
#  'BPOP',
#  'BPOPM',
#  'BPRN',
#  'BPTH',
#  'BPTS',
#  'BPYPM',
#  'BPYPN',
#  'BPYPO',
#  'BPYPP',
#  'BRAG',
#  'BRCN',
#  'BREZ',
#  'BREZR',
#  'BREZW',
#  'BRID',
#  'BRIV',
#  'BRIVU',
#  'BRIVW',
#  'BRKL',
#  'BRKR',
#  'BRKS',
#  'BRLI',
#  'BRLIR',
#  'BRLIU',
#  'BRLIW',
#  'BRLT',
#  'BROG',
#  'BROGW',
#  'BRP',
#  'BRPM',
#  'BRPMU',
#  'BRPMW',
#  'BRQS',
#  'BRTX',
#  'BRY',
#  'BRZE',
#  'BSAE',
#  'BSBE',
#  'BSBK',
#  'BSCE',
#  'BSCL',
#  'BSCM',
#  'BSCN',
#  'BSCO',
#  'BSCP',
#  'BSCQ',
#  'BSCR',
#  'BSCS',
#  'BSCT',
#  'BSCU',
#  'BSCV',
#  'BSDE',
#  'BSET',
#  'BSFC',
#  'BSGA',
#  'BSGAR',
#  'BSGAU',
#  'BSGM',
#  'BSJL',
#  'BSJM',
#  'BSJN',
#  'BSJO',
#  'BSJP',
#  'BSJQ',
#  'BSJR',
#  'BSJS',
#  'BSJT',
#  'BSKY',
#  'BSKYU',
#  'BSKYW',
#  'BSML',
#  'BSMM',
#  'BSMN',
#  'BSMO',
#  'BSMP',
#  'BSMQ',
#  'BSMR',
#  'BSMS',
#  'BSMT',
#  'BSMU',
#  'BSMV',
#  'BSQR',
#  'BSRR',
#  'BSVN',
#  'BSY',
#  'BTAI',
#  'BTAQ',
#  'BTAQU',
#  'BTAQW',
#  'BTB',
#  'BTBD',
#  'BTBDW',
#  'BTBT',
#  'BTCS',
#  'BTCY',
#  'BTEC',
#  'BTF',
#  'BTNB',
#  'BTRS',
#  'BTRSW',
#  'BTTX',
#  'BTWN',
#  'BTWNU',
#  'BTWNW',
#  'BTX',
#  'BUG',
#  'BUSE',
#  'BVS',
#  'BVXV',
#  'BWAC',
#  'BWACU',
#  'BWACW',
#  'BWAY',
#  'BWB',
#  'BWBBP',
#  'BWC',
#  'BWCAU',
#  'BWCAW',
#  'BWEN',
#  'BWFG',
#  'BWMN',
#  'BWMX',
#  'BXRX',
#  'BYFC',
#  'BYND',
#  'BYRN',
#  'BYSI',
#  'BYTS',
#  'BYTSU',
#  'BYTSW',
#  'BZ',
#  'BZUN',
#  'CAAS',
#  'CABA',
#  'CAC',
#  'CACC',
#  'CACG',
#  'CADL',
#  'CAKE',
#  'CALA',
#  'CALB',
#  'CALM',
#  'CALT',
#  'CAMP',
#  'CAMT',
#  'CAN',
#  'CAPR',
#  'CAR',
#  'CARA',
#  'CARE',
#  'CARG',
#  'CARV',
#  'CARZ',
#  'CASA',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CATC',
#  'CATH',
#  'CATY',
#  'CBAN',
#  'CBAT',
#  'CBAY',
#  'CBFV',
#  'CBIO',
#  'CBNK',
#  'CBRGU',
#  'CBRL',
#  'CBSH',
#  'CBTX',
#  'CCAI',
#  'CCAIU',
#  'CCAIW',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCCC',
#  'CCD',
#  'CCEL',
#  'CCEP',
#  'CCLP',
#  'CCMP',
#  'CCNC',
#  'CCNE',
#  'CCNEP',
#  'CCOI',
#  'CCRN',
#  'CCSI',
#  'CCTSU',
#  'CCXI',
#  'CD',
#  'CDAK',
#  'CDAQU',
#  'CDC',
#  'CDEV',
#  'CDK',
#  'CDL',
#  'CDLX',
#  'CDMO',
#  'CDNA',
#  'CDNS',
#  'CDTX',
#  'CDW',
#  'CDXC',
#  'CDXS',
#  'CDZI',
#  'CDZIP',
#  'CECE',
#  'CEFA',
#  'CELC',
#  'CELH',
#  'CELU',
#  'CELUW',
#  'CEMI',
#  'CENQ',
#  'CENQU',
#  'CENQW',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CERE',
#  'CERN',
#  'CERS',
#  'CERT',
#  'CETX',
#  'CETXP',
#  'CETXW',
#  'CEVA',
#  'CEY',
#  'CFA',
#  'CFB',
#  'CFBK',
#  'CFFE',
#  'CFFEU',
#  'CFFEW',
#  'CFFI',
#  'CFFN',
#  'CFFVU',
#  'CFFVW',
#  'CFIV',
#  'CFIVU',
#  'CFIVW',
#  'CFLT',
#  'CFMS',
#  'CFO',
#  'CFRX',
#  'CFV',
#  'CFVI',
#  'CFVIU',
#  'CFVIW',
#  'CG',
#  'CGABL',
#  'CGBD',
#  'CGC',
#  'CGEM',
#  'CGEN',
#  'CGNT',
#  'CGNX',
#  'CGO',
#  'CGRN',
#  'CGTX',
#  'CHB',
#  'CHCI',
#  'CHCO',
#  'CHDN',
#  'CHEF',
#  'CHEK',
#  'CHEKZ',
#  'CHI',
#  'CHK',
#  'CHKEL',
#  'CHKEW',
#  'CHKEZ',
#  'CHKP',
#  'CHMG',
#  'CHNA',
#  'CHNG',
#  'CHNGU',
#  'CHNR',
#  'CHPM',
#  'CHPMU',
#  'CHPMW',
#  'CHRS',
#  'CHRW',
#  'CHSCL',
#  'CHSCM',
#  'CHSCN',
#  'CHSCO',
#  'CHSCP',
#  'CHTR',
#  'CHUY',
#  'CHW',
#  'CHWA',
#  'CHWAU',
#  'CHWAW',
#  'CHX',
#  'CHY',
#  'CIBR',
#  'CID',
#  'CIDM',
#  'CIFR',
#  'CIFRW',
#  'CIGI',
#  'CIH',
#  'CIIG',
#  'CIIGU',
#  'CIIGW',
#  'CIL',
#  ...]

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: numpy>=1.14.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import preprocessing, utils 
import numpy as np
from collections import deque

# %%
features = ['adjclose', 'volume', 'open', 'high', 'low']

# %%
# loads data from yahoo finance based on a ticker string, ensures all requist columns are in the 
# DataFrame, adds date col if it doesn't exist (uses index values), splits the data by date into 
# training and testing sets 
def get_data(ticker, window=50, predict=1):
    try:
        df = si.get_data(ticker)
    except TypeError:
        print('ticker not string type')
    
    output = {}
    output['DataFrame'] = df.copy()

    for col in features:
        if col not in df.columns:
            return print(f'{col} missing')

    if 'date' not in df.columns:
        df['date'] = df.index

    # for col in features:
    #     scaler = preprocessing.MinMaxScaler()
    #     df[col] = scaler.fit_transform()
    # scaling data unfinished 

    df['future'] = df['adjclose'].shift(-predict)
    window_seq = np.array(df[features].tail(window))
    df.dropna(inplace=True)

    feat_date = deque(maxlen=window)
    feat_date_future = []
    temp = zip(df[features + ['date']].values, df['future'].values)

    for x, y in temp:
        feat_date.append(x)
        if len(feat_date) == window:
            feat_date_future.append([np.array(feat_date), y])
    
    # print(list([i[:len(features)] for i in feat_date]))
    # print(list([i[:len(features)] for i in feat_date]) + list(window_seq))

    window_seq = list([i[:len(features)] for i in feat_date]) + list(window_seq)
    window_seq = np.array(window_seq).astype(np.float32)
    
    output['window_seq'] = window_seq

    x = []
    y = []

    for X, Y in feat_date_future:
        x.append(X)
        y.append(Y)

    x = np.array(x)
    y = np.array(y)

    # print(x)

    train_size = int(.8 * len(x))
    output['train_x'] = x[:train_size]
    output['train_y'] = y[:train_size]
    output['test_x'] = x[train_size:]
    output['test_y'] = y[train_size:]

    utils.shuffle(output['train_x'], output['train_y'])
    utils.shuffle(output['test_x'], output['test_y'])

    dates = output['test_x'][:, -1, -1]
    output['DataFrame_test'] = output['DataFrame'].loc[dates]
    output['DataFrame_test'].drop_duplicates(keep='first')
    output['train_x'] = output['train_x'][:, :, :len(features)].astype(np.float32)
    output['test_x'] = output['test_x'][:, :, :len(features)].astype(np.float32)
    return output

# %%
get_data('AAPL')
# Out:
# {'DataFrame':                   open        high         low       close    adjclose  \
#  1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100453
#  1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095213
#  1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088224
#  1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090408
#  1980-12-18    0.118862    0.119420    0.118862    0.118862    0.093029
#  ...                ...         ...         ...         ...         ...
#  2021-11-19  157.649994  161.020004  156.529999  160.550003  160.550003
#  2021-11-22  161.679993  165.699997  161.000000  161.020004  161.020004
#  2021-11-23  161.119995  161.800003  159.059998  161.410004  161.410004
#  2021-11-24  160.750000  162.139999  159.639999  161.940002  161.940002
#  2021-11-26  159.570007  160.449997  156.360001  156.809998  156.809998
#
#                 volume ticker
#  1980-12-12  469033600   AAPL
#  1980-12-15  175884800   AAPL
#  1980-12-16  105728000   AAPL
#  1980-12-17   86441600   AAPL
#  1980-12-18   73449600   AAPL
#  ...               ...    ...
#  2021-11-19  117147500   AAPL
#  2021-11-22  117467900   AAPL
#  2021-11-23   96041900   AAPL
#  2021-11-24   69463600   AAPL
#  2021-11-26   76959800   AAPL
#
#  [10328 rows x 7 columns],
#  'window_seq': array([[1.4857315e+02, 6.8034096e+07, 1.4844000e+02, 1.4897000e+02,
#          1.4722000e+02],
#         [1.4584714e+02, 1.2986880e+08, 1.4882001e+02, 1.4882001e+02,
#          1.4575999e+02],
#         [1.4273169e+02, 1.2347890e+08, 1.4380000e+02, 1.4484000e+02,
#          1.4127000e+02],
#         [1.4322096e+02, 7.5834000e+07, 1.4392999e+02, 1.4460001e+02,
#          1.4278000e+02],
#         [1.4563745e+02, 7.6404304e+07, 1.4445000e+02, 1.4642999e+02,
#          1.4370000e+02],
#         [1.4661603e+02, 6.4838200e+07, 1.4664999e+02, 1.4708000e+02,
#          1.4564000e+02],
#         [1.4670589e+02, 5.3477900e+07, 1.4566000e+02, 1.4747000e+02,
#          1.4556000e+02],
#         [1.4515814e+02, 7.4150704e+07, 1.4547000e+02, 1.4596001e+02,
#          1.4382001e+02],
#         [1.4170319e+02, 1.0897230e+08, 1.4325000e+02, 1.4475000e+02,
#          1.4169000e+02],
#         [1.4262186e+02, 7.4602000e+07, 1.4247000e+02, 1.4445000e+02,
#          1.4203000e+02],
#         [1.4129379e+02, 8.8934200e+07, 1.4366000e+02, 1.4438000e+02,
#          1.4128000e+02],
#         [1.4244211e+02, 9.4639600e+07, 1.4189999e+02, 1.4292000e+02,
#          1.3911000e+02],
#         [1.3893723e+02, 9.8322000e+07, 1.4175999e+02, 1.4221001e+02,
#          1.3827000e+02],
#         [1.4090436e+02, 8.0861104e+07, 1.3949001e+02, 1.4224001e+02,
#          1.3936000e+02],
#         [1.4179306e+02, 8.3221104e+07, 1.3947000e+02, 1.4214999e+02,
#          1.3837000e+02],
#         [1.4308118e+02, 6.1732700e+07, 1.4306000e+02, 1.4422000e+02,
#          1.4272000e+02],
#         [1.4269174e+02, 5.8718700e+07, 1.4403000e+02, 1.4417999e+02,
#          [1.48573151e+02, 6.80340960e+07, 1.48440002e+02, 1.48970001e+02,
#           1.47220001e+02],
#          ...,
#          [1.57869995e+02, 1.37827696e+08, 1.53710007e+02, 1.58669998e+02,
#           1.53050003e+02],
#          [1.60550003e+02, 1.17147504e+08, 1.57649994e+02, 1.61020004e+02,
#           1.56529999e+02],
#          [1.61020004e+02, 1.17467904e+08, 1.61679993e+02, 1.65699997e+02,
#           1.61000000e+02]],
#
#         [[1.48812805e+02, 8.32812960e+07, 1.48559998e+02, 1.49440002e+02,
#           1.46369995e+02],
#          [1.48573151e+02, 6.80340960e+07, 1.48440002e+02, 1.48970001e+02,
#           1.47220001e+02],
#          [1.45847137e+02, 1.29868800e+08, 1.48820007e+02, 1.48820007e+02,
#           1.45759995e+02],
#          ...,
#          [1.60550003e+02, 1.17147504e+08, 1.57649994e+02, 1.61020004e+02,
#           1.56529999e+02],
#          [1.61020004e+02, 1.17467904e+08, 1.61679993e+02, 1.65699997e+02,
#           1.61000000e+02],
#          [1.61410004e+02, 9.60419040e+07, 1.61119995e+02, 1.61800003e+02,
#           1.59059998e+02]],
#
#         [[1.48573151e+02, 6.80340960e+07, 1.48440002e+02, 1.48970001e+02,
#           1.47220001e+02],
#          [1.45847137e+02, 1.29868800e+08, 1.48820007e+02, 1.48820007e+02,
#           1.45759995e+02],
#          [1.42731689e+02, 1.23478896e+08, 1.43800003e+02, 1.44839996e+02,
#           1.41270004e+02],
#          ...,
#          [1.61020004e+02, 1.17467904e+08, 1.61679993e+02, 1.65699997e+02,
#           1.61000000e+02],
#          [1.61410004e+02, 9.60419040e+07, 1.61119995e+02, 1.61800003e+02,
#           1.59059998e+02],
#          [1.61940002e+02, 6.94636000e+07, 1.60750000e+02, 1.62139999e+02,
#           1.59639999e+02]]], dtype=float32),
#  'test_y': array([ 15.01015949,  15.36309338,  15.41347408, ..., 161.41000366,
#         161.94000244, 156.80999756]),
#  'DataFrame_test':                   open        high         low       close    adjclose  \
#  2013-09-27   17.277857   17.309643   17.168571   17.241072   15.199065
#  2013-09-30   17.044643   17.202143   16.943214   17.026787   15.010159
#  2013-10-01   17.087500   17.469286   17.084999   17.427143   15.363093
#  2013-10-02   17.343929   17.564285   17.276787   17.484285   15.413474
#  2013-10-03   17.518213   17.583929   17.169287   17.264643   15.219840
#  ...                ...         ...         ...         ...         ...
#  2021-11-18  153.710007  158.669998  153.050003  157.869995  157.869995
#  2021-11-19  157.649994  161.020004  156.529999  160.550003  160.550003
#  2021-11-22  161.679993  165.699997  161.000000  161.020004  161.020004
#  2021-11-23  161.119995  161.800003  159.059998  161.410004  161.410004
#  2021-11-24  160.750000  162.139999  159.639999  161.940002  161.940002
#
#                 volume ticker
#  2013-09-27  228040400   AAPL
#  2013-09-30  260156400   AAPL
#  2013-10-01  353883600   AAPL
#  2013-10-02  289184000   AAPL
#  2013-10-03  322753200   AAPL
#  ...               ...    ...
#  2021-11-18  137827700   AAPL
#  2021-11-19  117147500   AAPL
#  2021-11-22  117467900   AAPL
#  2021-11-23   96041900   AAPL
#  2021-11-24   69463600   AAPL
#
#  [2056 rows x 7 columns]}
