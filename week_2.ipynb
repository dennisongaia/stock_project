# %% [markdown]
# # Week 2

# %% [markdown]
# Because of my lack of expertise when it comes to the stock market, I thought using machine learning might be a better approach, rather than manually trying to interpret complex technical indicators like I did last week. This week I began refreshing my Tensorflow knowledge, and based on many articles that I read this week (such as this: https://cs230.stanford.edu/projects_fall_2019/reports/26254244.pdf) I decided to work on creating a Long Short-Term Memory (LSTM) Recurrent neural network, as it is used for time series forecasting. I began by getting data using yahoo_fin and working on preprocessing it. By next week I hope to have built and trained my model so that I can start implementing my new technique. For my trades this week I reutilized my technical indicator approach from last week.

# %%
pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.8.9.1)
# Requirement already satisfied: requests-html in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (1.3.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (2.26.0)
# Requirement already satisfied: feedparser in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from yahoo_fin) (6.0.8)
# Requirement already satisfied: sgmllib3k in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->yahoo_fin) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->yahoo_fin) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.2.6)
# Requirement already satisfied: parse in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: bs4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: w3lib in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: pyquery in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: fake-useragent in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.62.3)
# Requirement already satisfied: websockets<10.0,>=9.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (9.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from bs4->requests-html->yahoo_fin) (4.10.0)
# Requirement already satisfied: lxml>=2.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (4.6.4)
# Requirement already satisfied: cssselect>0.7.9 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (1.3.4)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from yahoo_fin import stock_info as si

# %%
si.tickers_nasdaq()
# Out:
# ['AACG',
#  'AACI',
#  'AACIU',
#  'AACIW',
#  'AADI',
#  'AADR',
#  'AAL',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPL',
#  'AATC',
#  'AAWW',
#  'AAXJ',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEO',
#  'ABGI',
#  'ABIO',
#  'ABMD',
#  'ABNB',
#  'ABOS',
#  'ABSI',
#  'ABST',
#  'ABTX',
#  'ABUS',
#  'ABVC',
#  'ACAD',
#  'ACAH',
#  'ACAHU',
#  'ACAHW',
#  'ACB',
#  'ACBA',
#  'ACBAU',
#  'ACBAW',
#  'ACBI',
#  'ACCD',
#  'ACER',
#  'ACET',
#  'ACEV',
#  'ACEVU',
#  'ACEVW',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACHC',
#  'ACHL',
#  'ACHV',
#  'ACIU',
#  'ACIW',
#  'ACKIT',
#  'ACKIU',
#  'ACKIW',
#  'ACLS',
#  'ACMR',
#  'ACNB',
#  'ACOR',
#  'ACQR',
#  'ACQRU',
#  'ACQRW',
#  'ACRS',
#  'ACRX',
#  'ACST',
#  'ACT',
#  'ACTD',
#  'ACTDU',
#  'ACTDW',
#  'ACTG',
#  'ACVA',
#  'ACWI',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADALU',
#  'ADAP',
#  'ADBE',
#  'ADER',
#  'ADERU',
#  'ADERW',
#  'ADES',
#  'ADGI',
#  'ADI',
#  'ADIL',
#  'ADILW',
#  'ADMA',
#  'ADMP',
#  'ADN',
#  'ADNWW',
#  'ADOC',
#  'ADOCR',
#  'ADOCW',
#  'ADP',
#  'ADPT',
#  'ADRE',
#  'ADSK',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADVWW',
#  'ADXN',
#  'ADXS',
#  'AEAC',
#  'AEACU',
#  'AEACW',
#  'AEAEU',
#  'AEHA',
#  'AEHAU',
#  'AEHAW',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEMD',
#  'AEP',
#  'AEPPL',
#  'AEPPZ',
#  'AERC',
#  'AERI',
#  'AESE',
#  'AEY',
#  'AEYE',
#  'AEZS',
#  'AFACU',
#  'AFAQ',
#  'AFAQU',
#  'AFAQW',
#  'AFBI',
#  'AFCG',
#  'AFIB',
#  'AFIN',
#  'AFINO',
#  'AFINP',
#  'AFMD',
#  'AFRM',
#  'AFYA',
#  'AGBA',
#  'AGBAR',
#  'AGBAU',
#  'AGBAW',
#  'AGC',
#  'AGCUU',
#  'AGCWW',
#  'AGEN',
#  'AGFS',
#  'AGFY',
#  'AGGR',
#  'AGGRU',
#  'AGGRW',
#  'AGIL',
#  'AGILW',
#  'AGIO',
#  'AGLE',
#  'AGMH',
#  'AGNC',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGNG',
#  'AGRI',
#  'AGRIW',
#  'AGRX',
#  'AGTC',
#  'AGYS',
#  'AGZD',
#  'AHCO',
#  'AHI',
#  'AHPA',
#  'AHPAU',
#  'AHPAW',
#  'AHPI',
#  'AIA',
#  'AIH',
#  'AIHS',
#  'AIKI',
#  'AIMC',
#  'AINV',
#  'AIP',
#  'AIQ',
#  'AIRG',
#  'AIRR',
#  'AIRS',
#  'AIRT',
#  'AIRTP',
#  'AKAM',
#  'AKBA',
#  'AKIC',
#  'AKICU',
#  'AKICW',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKU',
#  'AKUS',
#  'AKYA',
#  'ALAC',
#  'ALACR',
#  'ALACU',
#  'ALACW',
#  'ALBO',
#  'ALCO',
#  'ALDX',
#  'ALEC',
#  'ALF',
#  'ALFIW',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIM',
#  'ALJJ',
#  'ALKS',
#  'ALKT',
#  'ALLK',
#  'ALLO',
#  'ALLT',
#  'ALNA',
#  'ALNY',
#  'ALORU',
#  'ALOT',
#  'ALPA',
#  'ALPAU',
#  'ALPAW',
#  'ALPN',
#  'ALPP',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALT',
#  'ALTM',
#  'ALTO',
#  'ALTR',
#  'ALTU',
#  'ALTUU',
#  'ALTUW',
#  'ALTY',
#  'ALVR',
#  'ALXO',
#  'ALYA',
#  'ALZN',
#  'AMAL',
#  'AMAO',
#  'AMAOU',
#  'AMAOW',
#  'AMAT',
#  'AMBA',
#  'AMCI',
#  'AMCIU',
#  'AMCIW',
#  'AMCX',
#  'AMD',
#  'AMED',
#  'AMEH',
#  'AMGN',
#  'AMKR',
#  'AMNB',
#  'AMOT',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPL',
#  'AMRK',
#  'AMRN',
#  'AMRS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMSWA',
#  'AMTB',
#  'AMTI',
#  'AMTX',
#  'AMWD',
#  'AMYT',
#  'AMZN',
#  'ANAB',
#  'ANAT',
#  'ANDE',
#  'ANEB',
#  'ANGI',
#  'ANGL',
#  'ANGN',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANPC',
#  'ANSS',
#  'ANTE',
#  'ANY',
#  'ANZU',
#  'ANZUU',
#  'ANZUW',
#  'AOSL',
#  'AOUT',
#  'APA',
#  'APAC',
#  'APACU',
#  'APACW',
#  'APDN',
#  'APEI',
#  'APEN',
#  'API',
#  'APLS',
#  'APLT',
#  'APM',
#  'APMI',
#  'APMIU',
#  'APMIW',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPH',
#  'APPHW',
#  'APPN',
#  'APPS',
#  'APR',
#  'APRE',
#  'APTM',
#  'APTMU',
#  'APTMW',
#  'APTO',
#  'APTX',
#  'APVO',
#  'APWC',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQST',
#  'AQWA',
#  'ARAV',
#  'ARAY',
#  'ARBE',
#  'ARBEW',
#  'ARBG',
#  'ARBGU',
#  'ARBGW',
#  'ARBK',
#  'ARBKL',
#  'ARCB',
#  'ARCC',
#  'ARCE',
#  'ARCKU',
#  'ARCT',
#  'ARDS',
#  'ARDX',
#  'AREC',
#  'ARGU',
#  'ARGUU',
#  'ARGUW',
#  'ARGX',
#  'ARHS',
#  'ARIZU',
#  'ARKO',
#  'ARKOW',
#  'ARKR',
#  'ARLP',
#  'ARNA',
#  'AROW',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARRW',
#  'ARRWU',
#  'ARRWW',
#  'ARRY',
#  'ARTA',
#  'ARTAU',
#  'ARTAW',
#  'ARTE',
#  'ARTEU',
#  'ARTEW',
#  'ARTL',
#  'ARTLW',
#  'ARTNA',
#  'ARTW',
#  'ARVL',
#  'ARVN',
#  'ARWR',
#  'ARYD',
#  'ARYE',
#  'ASAX',
#  'ASAXU',
#  'ASAXW',
#  'ASET',
#  'ASLE',
#  'ASLEW',
#  'ASLN',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASO',
#  'ASPA',
#  'ASPAU',
#  'ASPAW',
#  'ASPC',
#  'ASPCU',
#  'ASPCW',
#  'ASPS',
#  'ASPU',
#  'ASRT',
#  'ASRV',
#  'ASTC',
#  'ASTE',
#  'ASTL',
#  'ASTLW',
#  'ASTR',
#  'ASTRW',
#  'ASTS',
#  'ASTSW',
#  'ASUR',
#  'ASYS',
#  'ATAI',
#  'ATAX',
#  'ATCOL',
#  'ATCX',
#  'ATEC',
#  'ATER',
#  'ATEX',
#  'ATHA',
#  'ATHE',
#  'ATHX',
#  'ATIF',
#  'ATLC',
#  'ATLCL',
#  'ATLCP',
#  'ATLO',
#  'ATNF',
#  'ATNFW',
#  'ATNI',
#  'ATNX',
#  'ATOM',
#  'ATOS',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATRS',
#  'ATSG',
#  'ATSPT',
#  'ATSPU',
#  'ATSPW',
#  'ATVC',
#  'ATVCU',
#  'ATVCW',
#  'ATVI',
#  'ATXI',
#  'ATXS',
#  'ATY',
#  'AUB',
#  'AUBAP',
#  'AUBN',
#  'AUDC',
#  'AUGX',
#  'AUID',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AURC',
#  'AURCU',
#  'AURCW',
#  'AUROW',
#  'AUTL',
#  'AUTO',
#  'AUUD',
#  'AUUDW',
#  'AUVI',
#  'AUVIP',
#  'AVACU',
#  'AVAH',
#  'AVAV',
#  'AVCO',
#  'AVCT',
#  'AVCTW',
#  'AVDL',
#  'AVDX',
#  'AVEO',
#  'AVGO',
#  'AVGOP',
#  'AVGR',
#  'AVHI',
#  'AVHIU',
#  'AVHIW',
#  'AVID',
#  'AVIR',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVPTW',
#  'AVRO',
#  'AVT',
#  'AVTE',
#  'AVTX',
#  'AVXL',
#  'AWH',
#  'AWRE',
#  'AXDX',
#  'AXGN',
#  'AXLA',
#  'AXNX',
#  'AXON',
#  'AXSM',
#  'AXTI',
#  'AY',
#  'AYLA',
#  'AYRO',
#  'AYTU',
#  'AZN',
#  'AZPN',
#  'AZYO',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BASE',
#  'BATRA',
#  'BATRK',
#  'BBBY',
#  'BBCP',
#  'BBGI',
#  'BBH',
#  'BBI',
#  'BBIG',
#  'BBIO',
#  'BBLG',
#  'BBLGW',
#  'BBQ',
#  'BBSI',
#  'BCAB',
#  'BCAC',
#  'BCACU',
#  'BCACW',
#  'BCBP',
#  'BCDA',
#  'BCDAW',
#  'BCEL',
#  'BCLI',
#  'BCML',
#  'BCOR',
#  'BCOV',
#  'BCOW',
#  'BCPC',
#  'BCRX',
#  'BCSAU',
#  'BCTX',
#  'BCTXW',
#  'BCYC',
#  'BDSI',
#  'BDSX',
#  'BDTX',
#  'BEAM',
#  'BEAT',
#  'BEATW',
#  'BECN',
#  'BEEM',
#  'BEEMW',
#  'BELFA',
#  'BELFB',
#  'BENE',
#  'BENER',
#  'BENEU',
#  'BENEW',
#  'BFC',
#  'BFI',
#  'BFIIW',
#  'BFIN',
#  'BFIT',
#  'BFRA',
#  'BFRI',
#  'BFRIW',
#  'BFST',
#  'BGCP',
#  'BGFV',
#  'BGNE',
#  'BGRN',
#  'BGRY',
#  'BGRYW',
#  'BHAC',
#  'BHACU',
#  'BHACW',
#  'BHAT',
#  'BHF',
#  'BHFAL',
#  'BHFAM',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BHSE',
#  'BHSEU',
#  'BHSEW',
#  'BHTG',
#  'BIB',
#  'BICK',
#  'BIDU',
#  'BIGC',
#  'BIIB',
#  'BILI',
#  'BIMI',
#  'BIOC',
#  'BIOL',
#  'BIOT',
#  'BIOTU',
#  'BIOTW',
#  'BIOX',
#  'BIRD',
#  'BIS',
#  'BITF',
#  'BITS',
#  'BIVI',
#  'BJDX',
#  'BJK',
#  'BJRI',
#  'BKCC',
#  'BKCH',
#  'BKEP',
#  'BKEPP',
#  'BKNG',
#  'BKSC',
#  'BKYI',
#  'BL',
#  'BLBD',
#  'BLBX',
#  'BLCM',
#  'BLCN',
#  'BLCT',
#  'BLDE',
#  'BLDEW',
#  'BLDP',
#  'BLEUU',
#  'BLFS',
#  'BLFY',
#  'BLI',
#  'BLIN',
#  'BLKB',
#  'BLMN',
#  'BLNG',
#  'BLNGU',
#  'BLNGW',
#  'BLNK',
#  'BLNKW',
#  'BLPH',
#  'BLRX',
#  'BLSA',
#  'BLTS',
#  'BLTSU',
#  'BLTSW',
#  'BLU',
#  'BLUE',
#  'BLZE',
#  'BMAQ',
#  'BMAQR',
#  'BMAQU',
#  'BMAQW',
#  'BMBL',
#  'BMEA',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BMTC',
#  'BND',
#  'BNDW',
#  'BNDX',
#  'BNFT',
#  'BNGO',
#  'BNGOW',
#  'BNIX',
#  'BNIXR',
#  'BNIXW',
#  'BNNR',
#  'BNNRU',
#  'BNNRW',
#  'BNR',
#  'BNSO',
#  'BNTC',
#  'BNTX',
#  'BOKF',
#  'BOLT',
#  'BOMN',
#  'BON',
#  'BOOM',
#  'BOSC',
#  'BOTJ',
#  'BOTZ',
#  'BOXL',
#  'BPMC',
#  'BPOP',
#  'BPOPM',
#  'BPRN',
#  'BPTH',
#  'BPTS',
#  'BPYPM',
#  'BPYPN',
#  'BPYPO',
#  'BPYPP',
#  'BRAG',
#  'BRCN',
#  'BREZ',
#  'BREZR',
#  'BREZW',
#  'BRID',
#  'BRIV',
#  'BRIVU',
#  'BRIVW',
#  'BRKL',
#  'BRKR',
#  'BRKS',
#  'BRLI',
#  'BRLIR',
#  'BRLIU',
#  'BRLIW',
#  'BRLT',
#  'BROG',
#  'BROGW',
#  'BRP',
#  'BRPM',
#  'BRPMU',
#  'BRPMW',
#  'BRQS',
#  'BRTX',
#  'BRY',
#  'BRZE',
#  'BSAE',
#  'BSBE',
#  'BSBK',
#  'BSCE',
#  'BSCL',
#  'BSCM',
#  'BSCN',
#  'BSCO',
#  'BSCP',
#  'BSCQ',
#  'BSCR',
#  'BSCS',
#  'BSCT',
#  'BSCU',
#  'BSCV',
#  'BSDE',
#  'BSET',
#  'BSFC',
#  'BSGA',
#  'BSGAR',
#  'BSGAU',
#  'BSGM',
#  'BSJL',
#  'BSJM',
#  'BSJN',
#  'BSJO',
#  'BSJP',
#  'BSJQ',
#  'BSJR',
#  'BSJS',
#  'BSJT',
#  'BSKY',
#  'BSKYU',
#  'BSKYW',
#  'BSML',
#  'BSMM',
#  'BSMN',
#  'BSMO',
#  'BSMP',
#  'BSMQ',
#  'BSMR',
#  'BSMS',
#  'BSMT',
#  'BSMU',
#  'BSMV',
#  'BSQR',
#  'BSRR',
#  'BSVN',
#  'BSY',
#  'BTAI',
#  'BTAQ',
#  'BTAQU',
#  'BTAQW',
#  'BTB',
#  'BTBD',
#  'BTBDW',
#  'BTBT',
#  'BTCS',
#  'BTCY',
#  'BTEC',
#  'BTF',
#  'BTNB',
#  'BTRS',
#  'BTRSW',
#  'BTTX',
#  'BTWN',
#  'BTWNU',
#  'BTWNW',
#  'BTX',
#  'BUG',
#  'BUSE',
#  'BVS',
#  'BVXV',
#  'BWAC',
#  'BWACU',
#  'BWACW',
#  'BWAY',
#  'BWB',
#  'BWBBP',
#  'BWC',
#  'BWCAU',
#  'BWCAW',
#  'BWEN',
#  'BWFG',
#  'BWMN',
#  'BWMX',
#  'BXRX',
#  'BYFC',
#  'BYND',
#  'BYRN',
#  'BYSI',
#  'BYTS',
#  'BYTSU',
#  'BYTSW',
#  'BZ',
#  'BZUN',
#  'CAAS',
#  'CABA',
#  'CAC',
#  'CACC',
#  'CACG',
#  'CADL',
#  'CAKE',
#  'CALA',
#  'CALB',
#  'CALM',
#  'CALT',
#  'CAMP',
#  'CAMT',
#  'CAN',
#  'CAPR',
#  'CAR',
#  'CARA',
#  'CARE',
#  'CARG',
#  'CARV',
#  'CARZ',
#  'CASA',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CATC',
#  'CATH',
#  'CATY',
#  'CBAN',
#  'CBAT',
#  'CBAY',
#  'CBFV',
#  'CBIO',
#  'CBNK',
#  'CBRGU',
#  'CBRL',
#  'CBSH',
#  'CBTX',
#  'CCAI',
#  'CCAIU',
#  'CCAIW',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCCC',
#  'CCD',
#  'CCEL',
#  'CCEP',
#  'CCLP',
#  'CCMP',
#  'CCNC',
#  'CCNE',
#  'CCNEP',
#  'CCOI',
#  'CCRN',
#  'CCSI',
#  'CCTSU',
#  'CCXI',
#  'CD',
#  'CDAK',
#  'CDAQU',
#  'CDC',
#  'CDEV',
#  'CDK',
#  'CDL',
#  'CDLX',
#  'CDMO',
#  'CDNA',
#  'CDNS',
#  'CDTX',
#  'CDW',
#  'CDXC',
#  'CDXS',
#  'CDZI',
#  'CDZIP',
#  'CECE',
#  'CEFA',
#  'CELC',
#  'CELH',
#  'CELU',
#  'CELUW',
#  'CEMI',
#  'CENQ',
#  'CENQU',
#  'CENQW',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CERE',
#  'CERN',
#  'CERS',
#  'CERT',
#  'CETX',
#  'CETXP',
#  'CETXW',
#  'CEVA',
#  'CEY',
#  'CFA',
#  'CFB',
#  'CFBK',
#  'CFFE',
#  'CFFEU',
#  'CFFEW',
#  'CFFI',
#  'CFFN',
#  'CFFVU',
#  'CFFVW',
#  'CFIV',
#  'CFIVU',
#  'CFIVW',
#  'CFLT',
#  'CFMS',
#  'CFO',
#  'CFRX',
#  'CFV',
#  'CFVI',
#  'CFVIU',
#  'CFVIW',
#  'CG',
#  'CGABL',
#  'CGBD',
#  'CGC',
#  'CGEM',
#  'CGEN',
#  'CGNT',
#  'CGNX',
#  'CGO',
#  'CGRN',
#  'CGTX',
#  'CHB',
#  'CHCI',
#  'CHCO',
#  'CHDN',
#  'CHEF',
#  'CHEK',
#  'CHEKZ',
#  'CHI',
#  'CHK',
#  'CHKEL',
#  'CHKEW',
#  'CHKEZ',
#  'CHKP',
#  'CHMG',
#  'CHNA',
#  'CHNG',
#  'CHNGU',
#  'CHNR',
#  'CHPM',
#  'CHPMU',
#  'CHPMW',
#  'CHRS',
#  'CHRW',
#  'CHSCL',
#  'CHSCM',
#  'CHSCN',
#  'CHSCO',
#  'CHSCP',
#  'CHTR',
#  'CHUY',
#  'CHW',
#  'CHWA',
#  'CHWAU',
#  'CHWAW',
#  'CHX',
#  'CHY',
#  'CIBR',
#  'CID',
#  'CIDM',
#  'CIFR',
#  'CIFRW',
#  'CIGI',
#  'CIH',
#  'CIIG',
#  'CIIGU',
#  'CIIGW',
#  'CIL',
#  ...]

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: numpy>=1.14.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split
import numpy as np
from collections import deque

# %%
features = ['adjclose', 'volume', 'open', 'high', 'low']

# %%
# loads data from yahoo finance based on a ticker string, ensures all requist columns are in the 
# DataFrame, adds date col if it doesn't exist (uses index values), scales the data, then shuffles 
# and splits the data into training and testing sets 
def get_data(ticker, window=50, predict=1):
    df = si.get_data(ticker)
    output = {}
    output['original df'] = df.copy()
    print(df.index)

    for col in features: 
        if col not in features:
            return f'Missing {col}'
    
    if 'date' not in df.columns:
        df['date'] = df.index

    scaler = preprocessing.MinMaxScaler()
    df[features] = scaler.fit_transform(df[features])
    
    df['predicted'] = df['adjclose'].shift(-predict)
    last_values = np.array(df[features].tail(predict)) 
    df.dropna(inplace=True)
 
    predicted_val = df['predicted'].values
    features_dates = df[features + ['date']].values
    d = deque(maxlen=window)
    window_seq = []

    for i in range(len(features_dates)):
        d.append(features_dates[i])
        if len(d) == window:
            window_seq.append([np.array(d), predicted_val[i]])
    
    # final feature values left after broken up into window sequences, and last values 
    # len(last_values) = (window + predict)
    last_values = list([seq[:len(features)] for seq in d]) + list(last_values) 
    last_values = np.array(last_values).astype(np.float32)
    output['last values'] = last_values

    x, y = [], []
    for X, Y in window_seq:
        x.append(X)
        y.append(Y)

    x = np.array(x)
    y = np.array(y)

    output['x train'], output['x test'], output['y train'], output['y test'] = train_test_split(x, y, test_size=.2)

    dates = output['x test'][:, -1, -1]
    output['test df'] = output['original df'].loc[dates]
    output['test df'] = output['test df'].index.drop_duplicates()
    output['x train'] = output['x train'][:, :, : len(features)].astype(np.float32)
    output['x test'] = output['x test'][:, :, : len(features)].astype(np.float32)
    
    return output

# %%
get_data('AAPL')
# Out:
# DatetimeIndex(['1980-12-12', '1980-12-15', '1980-12-16', '1980-12-17',
#                '1980-12-18', '1980-12-19', '1980-12-22', '1980-12-23',
#                '1980-12-24', '1980-12-26',
#                ...
#                '2021-11-16', '2021-11-17', '2021-11-18', '2021-11-19',
#                '2021-11-22', '2021-11-23', '2021-11-24', '2021-11-26',
#                '2021-11-29', '2021-11-30'],
#               dtype='datetime64[ns]', length=10330, freq=None)
# {'original df':                   open        high         low       close    adjclose  \
#  1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100453
#  1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095213
#  1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088224
#  1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090408
#  1980-12-18    0.118862    0.119420    0.118862    0.118862    0.093029
#  ...                ...         ...         ...         ...         ...
#  2021-11-23  161.119995  161.800003  159.059998  161.410004  161.410004
#  2021-11-24  160.750000  162.139999  159.639999  161.940002  161.940002
#  2021-11-26  159.570007  160.449997  156.360001  156.809998  156.809998
#  2021-11-29  159.369995  161.190002  158.789993  160.240005  160.240005
#  2021-11-30  159.990005  165.520004  159.919998  165.300003  165.300003
#
#                 volume ticker
#  1980-12-12  469033600   AAPL
#  1980-12-15  175884800   AAPL
#  1980-12-16  105728000   AAPL
#  1980-12-17   86441600   AAPL
#  1980-12-18   73449600   AAPL
#  ...               ...    ...
#  2021-11-23   96041900   AAPL
#  2021-11-24   69463600   AAPL
#  2021-11-26   76959800   AAPL
#  2021-11-29   88748200   AAPL
#  2021-11-30  173758500   AAPL
#
#  [10330 rows x 7 columns],
#  'last values': array([[0.86343884, 0.01663768, 0.88937724, 0.8740721 , 0.8774161 ],
#         [0.8663994 , 0.01021796, 0.8901815 , 0.8726233 , 0.8867978 ],
#         [0.8810216 , 0.0102948 , 0.89339876, 0.88367057, 0.89251375],
#         [0.886943  , 0.00873637, 0.90701   , 0.8875946 , 0.9045672 ],
#         [0.88748676, 0.00720567, 0.900885  , 0.8899489 , 0.9040701 ],
#         [0.8781213 , 0.00999115, 0.89970946, 0.8808334 , 0.8932594 ],
#         [0.85721534, 0.01468305, 0.8859744 , 0.8735288 , 0.8800255 ],
#         [0.86277425, 0.01005196, 0.8811486 , 0.87171775, 0.88213795],
#         [0.8547381 , 0.01198309, 0.88851106, 0.8712952 , 0.8774781 ],
#         [0.8616866 , 0.01275184, 0.877622  , 0.8624814 , 0.8639958 ],
#         [0.8404785 , 0.01324801, 0.87675583, 0.8581953 , 0.8587768 ],
#         [0.85238165, 0.01089531, 0.8627115 , 0.85837644, 0.865549  ],
#         [0.8577592 , 0.0112133 , 0.86258775, 0.857833  , 0.85939807],
#         [0.86555356, 0.00831793, 0.8847989 , 0.8703293 , 0.886425  ],
#         [0.8631971 , 0.00791182, 0.89080024, 0.87008774, 0.8854309 ],
#         [0.8626534 , 0.00868436, 0.87991124, 0.873891  , 0.8807711 ],
#         [0.8547985 , 0.00984094, 0.88585067, 0.8644736 , 0.875987  ],
#         [0.85117316, 0.01061257, 0.8735387 , 0.85330546, 0.86455494],
#         [0.8683934 , 0.00941936, 0.8789213 , 0.8682768 , 0.87890714],
#         [0.874919  , 0.00914693, 0.8891917 , 0.8744343 , 0.8913333 ],
#         [0.88525116, 0.01153238, 0.8872118 , 0.8861457 , 0.8891588 ],
#         [0.89860433, 0.01029138, 0.9092373 , 0.9002115 , 0.9102211 ],
#         [0.9016255 , 0.00787141, 0.9196933 , 0.90371287, 0.9199756 ],
#         [0.9029547 , 0.00827593, 0.92037386, 0.9030488 , 0.9184223 ],
#         [0.89818144, 0.00793401, 0.92581844, 0.90630865, 0.9232064 ],
#         [0.89787936, 0.00683415, 0.91956955, 0.90141886, 0.91686904],
#         [0.9019881 , 0.00820484, 0.92359114, 0.910293  , 0.9255052 ],
#         [0.8991483 , 0.00755829, 0.92377675, 0.9035921 , 0.9222745 ],
#         [0.9216252 , 0.01348461, 0.92662275, 0.9243587 , 0.9299165 ],
#         [0.90488833, 0.01682248, 0.91053665, 0.90485984, 0.9093512 ],
#         [0.8998129 , 0.01005011, 0.92148757, 0.903411  , 0.9179874 ],
#         [0.9062176 , 0.00931357, 0.9194459 , 0.9146999 , 0.9232685 ],
#         [0.9150997 , 0.00734494, 0.9301493 , 0.9171146 , 0.9305379 ],
#         [0.91189724, 0.00813763, 0.9375118 , 0.9198915 , 0.9356325 ],
#         [0.91516477, 0.00881403, 0.9394297 , 0.91850305, 0.93202895],
#         [0.9100819 , 0.00741358, 0.93646   , 0.9146999 , 0.93265027],
#         [0.9123208 , 0.00765166, 0.92897373, 0.91385466, 0.93202895],
#         [0.8948333 , 0.00878338, 0.92786014, 0.9060069 , 0.9182981 ],
#         [0.8945308 , 0.00552438, 0.92130196, 0.901781  , 0.9172418 ],
#         [0.907359  , 0.00857393, 0.9180228 , 0.90763676, 0.9159992 ],
#         [0.9074195 , 0.00797975, 0.9300255 , 0.9165713 , 0.92811465],
#         [0.9134705 , 0.00798425, 0.9273652 , 0.91421694, 0.9275555 ],
#         [0.92853755, 0.01196595, 0.93392336, 0.93540615, 0.93780714],
#         [0.95504093, 0.01857105, 0.95069003, 0.9575612 , 0.95060605],
#         [0.9712577 , 0.01578458, 0.97506654, 0.97174776, 0.9722276 ],
#         [0.97410166, 0.01582775, 1.        , 1.        , 1.        ],
#         [0.9764616 , 0.01294079, 0.9965353 , 0.97645646, 0.9879466 ],
#         [0.9796686 , 0.0093596 , 0.9942462 , 0.97850895, 0.9915502 ],
#         [0.9486269 , 0.01036965, 0.9869456 , 0.9683067 , 0.9711713 ],
#         [0.96938187, 0.01195803, 0.9857081 , 0.972774  , 0.98626906],
#         [1.        , 0.02341241, 0.9895441 , 0.9989134 , 0.9932899 ]],
#        dtype=float32),
#  'x train': array([[[0.00207977, 0.04063026, 0.00256193, 0.00252994, 0.00243863],
#          [0.00215295, 0.03786936, 0.00237079, 0.00248682, 0.0023532 ],
#          [0.00207977, 0.0372627 , 0.00252326, 0.00247712, 0.00245083],
#          ...,
#          [0.00185557, 0.06339655, 0.00201615, 0.00213108, 0.0020248 ],
#          [0.00202418, 0.08283904, 0.00226694, 0.00237471, 0.00227997],
#          [0.00206958, 0.06127249, 0.00235864, 0.00239626, 0.00233989]],
#
#         [[0.16086929, 0.02040611, 0.17581995, 0.17357548, 0.17591323],
#          [0.1606143 , 0.01423912, 0.17547967, 0.17209646, 0.17552492],
#          [0.15771016, 0.02362055, 0.17518578, 0.17140222, 0.17137769],
#          ...,
#          [0.1676627 , 0.01711314, 0.18032095, 0.17802763, 0.18060412],
#          [0.16920054, 0.01808867, 0.18213063, 0.1799443 , 0.18288742],
#          [0.16937141, 0.0131842 , 0.18339896, 0.17986885, 0.1834466 ]],
#
#         [[0.01789369, 0.11440338, 0.02208289, 0.02180138, 0.02123208],
#          [0.01770655, 0.09094668, 0.02098691, 0.02089586, 0.02094583],
#          [0.01816049, 0.11010886, 0.02086759, 0.02120633, 0.02095914],
#          ...,
#          [0.02209405, 0.06285214, 0.02659052, 0.02621688, 0.02613596],
#          [0.0223275 , 0.06342069, 0.02596299, 0.02603362, 0.0260117 ],
#          [0.02228118, 0.12649052, 0.02678939, 0.0267257 , 0.02658863]],
#
#         ...,
#
#         [[0.00156272, 0.01602664, 0.00204045, 0.00200441, 0.00201093],
#          [0.0015841 , 0.00997968, 0.00201283, 0.00201789, 0.00201093],
#          [0.00150929, 0.03063473, 0.00204045, 0.00200441, 0.00194159],
#          ...,
#          [0.00147723, 0.01821182, 0.00197141, 0.00192356, 0.00189305],
#          [0.00147189, 0.01147822, 0.00191616, 0.00186966, 0.00189998],
#          [0.00144517, 0.02542834, 0.00190235, 0.00185619, 0.00183064]],
#
#         [[0.00105145, 0.08580291, 0.00118201, 0.00120507, 0.00118492],
#          [0.00106997, 0.06174333, 0.00123726, 0.00122663, 0.00120157],
#          [0.0010848 , 0.06173503, 0.00123173, 0.00124711, 0.00123152],
#          ...,
#          [0.00153967, 0.01856344, 0.00179187, 0.00180768, 0.00180069],
#          [0.00160822, 0.0385726 , 0.0018217 , 0.00187559, 0.00181732],
#          [0.00165732, 0.03459311, 0.00184932, 0.00191008, 0.00185727]],
#
#         [[0.00182084, 0.01643863, 0.00226142, 0.00222001, 0.00221896],
#          [0.00173205, 0.02790326, 0.0022476 , 0.00219306, 0.00210801],
#          [0.00179864, 0.02640322, 0.00212331, 0.00216611, 0.00213574],
#          ...,
#          [0.00195991, 0.0307449 , 0.00234428, 0.00236824, 0.0023299 ],
#          [0.00188757, 0.02423766, 0.00239952, 0.00235476, 0.0023299 ],
#          [0.00197104, 0.02892643, 0.00239952, 0.00239519, 0.00238538]]],
#        dtype=float32),
#  'x test': array([[[1.31496802e-01, 2.52865385e-02, 1.45936936e-01, 1.42621711e-01,
#           1.44164428e-01],
#          [1.33004457e-01, 2.26701349e-02, 1.45333707e-01, 1.43391415e-01,
#           1.45531297e-01],
#          [1.32497177e-01, 1.64072067e-02, 1.46076143e-01, 1.42531171e-01,
#           1.45034254e-01],
#          ...,
#          [1.36921555e-01, 2.17649452e-02, 1.51659876e-01, 1.48869812e-01,
#           1.50237709e-01],
#          [1.35977492e-01, 3.03112492e-02, 1.49448037e-01, 1.47556812e-01,
#           1.49461076e-01],
#          [1.44826114e-01, 4.97705564e-02, 1.60971239e-01, 1.57185525e-01,
#           1.59293264e-01]],
#
#         [[3.66706634e-04, 6.18233085e-02, 4.17761941e-04, 4.17729345e-04,
#           4.12585447e-04],
#          [3.75396339e-04, 1.31819909e-02, 4.10851120e-04, 4.14360780e-04,
#           4.16052382e-04],
#          [3.84080719e-04, 1.45356534e-02, 4.14303417e-04, 4.21097851e-04,
#           4.16052382e-04],
#          ...,
#          [8.99397710e-04, 1.10194497e-01, 9.56355128e-04, 1.03420857e-03,
#           9.63859144e-04],
#          [8.82028951e-04, 9.09670517e-02, 9.77069139e-04, 1.00726029e-03,
#           9.77726770e-04],
#          [8.99397710e-04, 8.98005217e-02, 1.01159851e-03, 1.02073443e-03,
#           9.91594279e-04]],
#
#         [[9.94140357e-02, 2.75244787e-02, 1.14078529e-01, 1.12657577e-01,
#           1.14414893e-01],
#          [9.95328724e-02, 2.65737455e-02, 1.14151441e-01, 1.12297520e-01,
#           1.14406012e-01],
#          [1.00975797e-01, 3.80534716e-02, 1.15214273e-01, 1.13813184e-01,
#           1.15495518e-01],
#          ...,
#          [1.05450243e-01, 5.11996225e-02, 1.21423334e-01, 1.19852148e-01,
#           1.21251501e-01],
#          [1.06345132e-01, 5.43328896e-02, 1.21208996e-01, 1.19681828e-01,
#           1.20585807e-01],
#          [1.04407795e-01, 5.78517355e-02, 1.22106098e-01, 1.19492099e-01,
#           1.20572485e-01]],
#
#         ...,
#
#         [[1.31703902e-03, 1.90931372e-02, 1.56400108e-03, 1.55973725e-03,
#           1.56020257e-03],
#          [1.31418556e-03, 1.46986367e-02, 1.55709637e-03, 1.53952604e-03,
#           1.54633506e-03],
#          [1.31418556e-03, 1.09500317e-02, 1.57090556e-03, 1.55300018e-03,
#           1.56020257e-03],
#          ...,
#          [1.42474868e-03, 4.16783318e-02, 1.73662941e-03, 1.72817649e-03,
#           1.69195712e-03],
#          [1.44192192e-03, 2.32099611e-02, 1.70901103e-03, 1.68101082e-03,
#           1.67114951e-03],
#          [1.47054403e-03, 2.42904779e-02, 1.70901103e-03, 1.71469629e-03,
#           1.69889082e-03]],
#
#         [[7.92838910e-05, 5.93076413e-03, 1.03575840e-04, 1.04430823e-04,
#           1.04013096e-04],
#          [8.72119490e-05, 4.80497535e-03, 1.10480483e-04, 1.07799344e-04,
#           1.14413757e-04],
#          [8.98545622e-05, 5.78287197e-03, 1.13932831e-04, 1.11167901e-04,
#           1.17880678e-04],
#          ...,
#          [1.61210672e-04, 2.08950024e-02, 2.17508685e-04, 2.18973291e-04,
#           2.11493054e-04],
#          [1.61210672e-04, 1.24712046e-02, 2.07151694e-04, 2.12230181e-04,
#           2.11493054e-04],
#          [1.63853241e-04, 2.09825300e-02, 2.10604048e-04, 2.15598702e-04,
#           2.14959975e-04]],
#
#         [[1.74090609e-01, 1.56140132e-02, 1.95216060e-01, 1.91565171e-01,
#           1.95422292e-01],
#          [1.73251852e-01, 1.52898803e-02, 1.95014983e-01, 1.91519901e-01,
#           1.95577621e-01],
#          [1.71299309e-01, 2.80029718e-02, 1.93885863e-01, 1.90071061e-01,
#           1.93014726e-01],
#          ...,
#          [1.75964773e-01, 1.83459707e-02, 1.96886525e-01, 1.92968726e-01,
#           1.97084293e-01],
#          [1.75163954e-01, 1.63138583e-02, 1.96871072e-01, 1.92289591e-01,
#           1.96773633e-01],
#          [1.76655158e-01, 2.97944359e-02, 1.96453452e-01, 1.95594758e-01,
#           1.97146431e-01]]], dtype=float32),
#  'y train': array([0.00198712, 0.17028274, 0.02300194, ..., 0.00143449, 0.00161008,
#         0.0019154 ]),
#  'y test': array([1.46784669e-01, 8.21231436e-04, 1.05256684e-01, ...,
#         1.48771674e-03, 1.61210667e-04, 1.75812864e-01]),
#  'test df': DatetimeIndex(['2016-07-27', '1998-03-06', '2014-01-24', '1991-02-04',
#                 '2008-03-13', '2007-11-27', '2002-06-13', '2002-08-28',
#                 '2000-12-28', '2001-12-21',
#                 ...
#                 '1987-07-01', '2017-04-06', '2000-11-16', '2017-04-28',
#                 '2015-01-05', '1982-07-20', '1982-10-22', '1994-12-05',
#                 '1985-11-04', '2015-06-24'],
#                dtype='datetime64[ns]', length=2056, freq=None)}
